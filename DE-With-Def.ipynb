# %% [markdown]
# # Jupyter SQL Magic Commands
#
# Jupyter Notebook provides **SQL Magic Commands** through the `ipython-sql` extension. These commands allow you to execute SQL queries directly inside notebook cells.
#
# ## Load the SQL Extension
#
# ```python
# %load_ext sql
# ```
#
# - Loads the **ipython-sql** extension into the current Jupyter Notebook session.
# - This command only needs to be executed **once** after opening the notebook.
#
# ## Connect to a MySQL Database
#
# ```python
# %sql mysql+mysqlconnector://root:123456@localhost/test
# ```
#
# This command establishes a connection to the MySQL database.
#
# ### Connection String Breakdown
#
# | Part | Description |
# |------|-------------|
# | `mysql+mysqlconnector` | Database dialect and Python driver used to connect to MySQL. |
# | `root` | MySQL username. |
# | `123456` | Password for the MySQL user. |
# | `localhost` | Database server address. |
# | `test` | Database name to connect to. |
#
# Once the connection is successful, all SQL queries can be executed directly in the notebook using the `%sql` or `%%sql` magic commands.
#
# ## Example
#
# ```python
# %load_ext sql
# %sql mysql+mysqlconnector://root:123456@localhost/test
# ```
#
# After connecting, you can run SQL queries such as:
#
# ```sql
# %%sql
# SELECT * FROM employees;
# ```

# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:123456@localhost/test

# %% [markdown]
# # Introduction to SQL
#
# **SQL (Structured Query Language)** is a standard language used to store, retrieve, update, and manage data in relational databases. It allows users to create databases, define tables, insert records, modify data, delete data, and query information efficiently.
#
# # Popular Database Providers
#
# ## MySQL
# **MySQL** is an open-source relational database management system (RDBMS) widely used for web applications. It is known for its speed, reliability, and ease of use.
#
# ## Oracle Database
# **Oracle Database** is a commercial relational database management system developed by Oracle Corporation. It is designed for enterprise applications that require high performance, security, and scalability.
#
# ## Microsoft SQL Server
# **Microsoft SQL Server** is a relational database management system developed by Microsoft. It is commonly used in enterprise environments and integrates well with Microsoft technologies.
#
# ## PostgreSQL
# **PostgreSQL** is an open-source object-relational database management system known for its advanced features, extensibility, and standards compliance.
#
# ## SQLite
# **SQLite** is a lightweight, serverless relational database that stores the entire database in a single file. It is commonly used in mobile and embedded applications.
#
# # Difference Between Popular Database Providers
#
# | Feature | MySQL | Oracle Database | Microsoft SQL Server | PostgreSQL | SQLite |
# |---------|-------|-----------------|----------------------|------------|---------|
# | License | Open Source | Commercial | Commercial | Open Source | Open Source |
# | Best For | Web Applications | Enterprise Applications | Microsoft Ecosystem | Advanced Applications | Mobile & Embedded Applications |
# | Scalability | High | Very High | High | Very High | Low |
# | Performance | Fast | Excellent | Excellent | Excellent | Good |
# | Platform | Cross-Platform | Cross-Platform | Windows/Linux | Cross-Platform | Cross-Platform |
# | Cost | Free (Community Edition) | Paid | Paid | Free | Free |

# %% [markdown]
# # Basic SQL Syntax
#
# Before jumping into the major topics, we will first learn the basic SQL syntax required to perform **CRUD operations**.
#
# **CRUD** stands for:
#
# - **C** – Create
# - **R** – Read
# - **U** – Update
# - **D** – Delete
#
# These operations form the foundation of working with relational databases.

# %% [markdown]
# # Create Database
#
# A **database** is created using the `CREATE DATABASE` statement.
#
# ## Syntax
#
# ```sql
# CREATE DATABASE database_name;
# ```
#
# ## Database Naming Convention
#
# The database name should be **meaningful** and follow a proper naming convention.
#
# **Example:**
#
# - `mk_de_test`
#   - `mk` → Company Name
#   - `de` → Data Engineering Team
#   - `test` → Sub-team or Project Name
#
# ## More Examples
#
# - `abc_hr_payroll`
#   - `abc` → Company Name
#   - `hr` → Human Resources Team
#   - `payroll` → Project Name
#
# - `xyz_sales_analytics`
#   - `xyz` → Company Name
#   - `sales` → Sales Team
#   - `analytics` → Project Name
#
# - `tech_fin_reporting`
#   - `tech` → Company Name
#   - `fin` → Finance Team
#   - `reporting` → Project Name
#
# - `acme_dev_inventory`
#   - `acme` → Company Name
#   - `dev` → Development Team
#   - `inventory` → Project Name

# %%
# %%sql
#
# create database db_test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %% [markdown]
# # Basic SQL Commands
#
# Before moving to advanced SQL concepts, let's understand some of the basic commands used to perform **CRUD (Create, Read, Update, Delete)** operations.
#
# ---
#
# # 1. SHOW DATABASES
#
# **Definition:**
#
# The `SHOW DATABASES` command is used to display all the databases available on the database server.
#
# ## Syntax
#
# ```sql
# SHOW DATABASES;
# ```
#
# ## Example
#
# ```sql
# SHOW DATABASES;
# ```
#
# ---

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 18 rows affected.
# [('db_test',),
#  ('de_test',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('tp_11',),
#  ('tp_11_question',),
#  ('tp_11_quiz',),
#  ('tp_730',),
#  ('tp_9',),
#  ('tp_9_question',),
#  ('tp_9_quiz',),
#  ('tp_karthi',),
#  ('tp_karthi_quiz',),
#  ('world',)]

# %% [markdown]
# # 2. USE DATABASE
#
# **Definition:**
#
# The `USE DATABASE` command is used to select/use a specific database database.
#
# ## Syntax
#
# ```sql
# USE database_name;
# ```
#
# ## Example
#
# ```sql
# USE mk_de_test;
# ```
#
# ---

# %%
# %%sql
# USE test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # 3. DROP DATABASE
#
# **Definition:**
#
# The `DROP DATABASE` command is used to permanently delete an existing database along with all its tables and data.
#
# ## Syntax
#
# ```sql
# DROP DATABASE database_name;
# ```
#
# ## Example
#
# ```sql
# DROP DATABASE mk_de_test;
# ```
#
# ---

# %%
# %%sql
# drop database tp_de_test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # 4. CREATE TABLE
#
# **Definition:**
#
# The `CREATE TABLE` command is used to create a new table by defining its columns and data types.
#
# ## Syntax
#
# ```sql
# CREATE TABLE table_name (
#     column1 datatype,
#     column2 datatype,
#     column3 datatype
# );
# ```
# ## Example
#
# ```sql
# CREATE TABLE employees (
#     emp_id INT,
#     emp_name VARCHAR(50),
#     salary DECIMAL(10,2)
# );
# ```
#
# ---

# %%
# %%sql
# create table employees_tp(
#     id int,
#     name varchar(100)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # 5. INSERT INTO
#
# **Definition:**
#
# The `INSERT INTO` command is used to insert new records into a table.
#
# ## Syntax
#
# ```sql
# INSERT INTO table_name (column1, column2, ...)
# VALUES (value1, value2, ...);
# ```
#
# ## Example
#
# ```sql
# INSERT INTO employees (emp_id, emp_name, salary)
# VALUES (1, 'Karthik', 50000);
# ```
#
# ---

# %%
# %%sql
# INSERT INTO employees_tp values
# (1,'Karthikeyan'),
# (2,'Gopal'),
# (3,'Raj'),
# (4,'Mani'),
# (5,'Divya'),
# (6,'Priya'),
# (7,'Anu'),
# (8,'Ramya'),
# (9,'Raja'),
# (10,'Manikandan');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 10 rows affected.
# []

# %% [markdown]
# # 6. SELECT
#
# **Definition:**
#
# The `SELECT` command is used to retrieve data from a table.
#
# ## Syntax
#
# ```sql
# SELECT * FROM table_name;
# ```
#
# ## Example
#
# ```sql
# SELECT * FROM employees;
# ```
#
# ---

# %%
# %%sql
# SELECT * FROM employees_tp;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 10 rows affected.
# [(1, 'Karthikeyan'),
#  (2, 'Gopal'),
#  (3, 'Raj'),
#  (4, 'Mani'),
#  (5, 'Divya'),
#  (6, 'Priya'),
#  (7, 'Anu'),
#  (8, 'Ramya'),
#  (9, 'Raja'),
#  (10, 'Manikandan')]

# %% [markdown]
# # 7. UPDATE
#
# **Definition:**
#
# The `UPDATE` command is used to modify existing records in a table.
#
# ## Syntax
#
# ```sql
# UPDATE table_name
# SET column_name = value
# WHERE condition;
# ```
#
# ## Example
#
# ```sql
# UPDATE employees
# SET salary = 60000
# WHERE emp_id = 1;
# ```
#
# ---

# %%
# %%sql
#
# UPDATE employees_tp
# SET name = "Gopal S"
# where id=2;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %% [markdown]
# # 8. DELETE
#
# **Definition:**
#
# The `DELETE` command is used to remove one or more records from a table.
#
# ## Syntax
#
# ```sql
# DELETE FROM table_name
# WHERE condition;
# ```
#
# ## Example
#
# ```sql
# DELETE FROM employees
# WHERE emp_id = 1;
# ```
#
# ---

# %%
# %%sql
# DELETE FROM employees_tp
# WHERE id = 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %% [markdown]
# # 9. TRUNCATE
#
# **Definition:**
#
# The `TRUNCATE` command removes all records from a table while keeping the table structure intact.
#
# ## Syntax
#
# ```sql
# TRUNCATE TABLE table_name;
# ```
#
# ## Example
#
# ```sql
# TRUNCATE TABLE employees;
# ```
#
# ---

# %%
# %%sql
#
# TRUNCATE TABLE employees_tp;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # 10. DROP TABLE
#
# **Definition:**
#
# The `DROP TABLE` command permanently deletes a table along with all its data and structure.
#
# ## Syntax
#
# ```sql
# DROP TABLE table_name;
# ```
#
# ## Example
#
# ```sql
# DROP TABLE employees;
# ```

# %%
# %%sql
# DROP TABLE employees_tp;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# ----

# %% [markdown]
# # Different Types of Table Creation
#
# ## 1. Normal Table
#
# **Definition:**
#
# A **Normal Table** is a regular database table used to store data permanently. The data remains in the table until it is explicitly updated, deleted, or the table is dropped.
#
# ## Syntax
#
# ```sql
# CREATE TABLE table_name (
#     column1 datatype,
#     column2 datatype,
#     column3 datatype
# );
# ```
#
# ## Example
#
# ```sql
# CREATE TABLE employees (
#     emp_id INT,
#     emp_name VARCHAR(100),
#     department VARCHAR(50),
#     salary DECIMAL(10,2)
# );
# ```
#
# ### Verify the Table
#
# ```sql
# DESC employees;
# ```
#
# or
#
# ```sql
# DESCRIBE employees;
# ```
#
# ### View the Table
#
# ```sql
# SELECT * FROM employees;
# ```

# %%
# %%sql
# CREATE TABLE employees (
#     emp_id INT,
#     emp_name VARCHAR(100),
#     department VARCHAR(50),
#     salary DECIMAL(10,2)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# DESC employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [('emp_id', 'int', 'YES', '', None, ''),
#  ('emp_name', 'varchar(100)', 'YES', '', None, ''),
#  ('department', 'varchar(50)', 'YES', '', None, ''),
#  ('salary', 'decimal(10,2)', 'YES', '', None, '')]

# %% [markdown]
# # 2. CTAS (Create Table As Select)
#
# **Definition:**
#
# **CTAS (Create Table As Select)** is used to create a new table from the result of a `SELECT` query. The new table will contain the data returned by the query.
#
# Suppose we already have a table named **`employees_day`** with **50 records**. We can use this table to create another table for experimentation without affecting the original data.
#
# ## Syntax
#
# ```sql
# CREATE TABLE new_table_name AS
# SELECT column_name(s)
# FROM existing_table
# WHERE condition;
# ```
#
# ## Example 1: Copy All Records
#
# ```sql
# CREATE TABLE employees_backup AS
# SELECT *
# FROM employees_day;
# ```
#
# ## Example 2: Copy Selected Columns
#
# ```sql
# CREATE TABLE employee_details AS
# SELECT emp_id, emp_name, department
# FROM employees_day;
# ```
#
# ## Example 3: Copy the Selected Columns or ALL with the specific Condition [WHERE]
# ```sql
# CREATE TABLE employee_details_50K_salary AS
# SELECT emp_id, emp_name, department
# FROM employees_day where salary >= 50000;
# ```
#
# ## Verify the New Table
#
# ```sql
# SELECT * FROM employees_backup;
# ```

# %%
# %%sql
# -- Copy ALl Datas
# CREATE TABLE employees_backup AS
# SELECT *
# FROM employees_day;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 50 rows affected.
# []

# %%
# %%sql
# -- Just Viewing the Data
# select * from employees_backup
# limit 10;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 10 rows affected.
# [(1, 'Arun Kumar', 'IT', Decimal('45000.00')),
#  (2, 'Priya Sharma', 'HR', Decimal('42000.00')),
#  (3, 'Karthik Raj', 'Finance', Decimal('55000.00')),
#  (4, 'Sneha Reddy', 'Marketing', Decimal('48000.00')),
#  (5, 'Rahul Verma', 'Sales', Decimal('47000.00')),
#  (6, 'Divya Nair', 'IT', Decimal('62000.00')),
#  (7, 'Vikram Singh', 'HR', Decimal('39000.00')),
#  (8, 'Meena Iyer', 'Finance', Decimal('53000.00')),
#  (9, 'Suresh Babu', 'IT', Decimal('61000.00')),
#  (10, 'Anjali Gupta', 'Marketing', Decimal('50000.00'))]

# %%
# %%sql
# -- Now Copying the Specific Data
#
# create table employees_details as
# select emp_id, emp_name
# from employees_day;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 50 rows affected.
# []

# %%
# %%sql
# select * from employees_details
# limit 10;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 10 rows affected.
# [(1, 'Arun Kumar'),
#  (2, 'Priya Sharma'),
#  (3, 'Karthik Raj'),
#  (4, 'Sneha Reddy'),
#  (5, 'Rahul Verma'),
#  (6, 'Divya Nair'),
#  (7, 'Vikram Singh'),
#  (8, 'Meena Iyer'),
#  (9, 'Suresh Babu'),
#  (10, 'Anjali Gupta')]

# %%
# %%sql
# -- Example 3
# CREATE TABLE employee_details_50K_salary AS
# SELECT emp_id, emp_name, department
# FROM employees_day where salary >= 50000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 29 rows affected.
# []

# %%
# %%sql
# SELECT * from employee_details_50K_salary;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 29 rows affected.
# [(3, 'Karthik Raj', 'Finance'),
#  (6, 'Divya Nair', 'IT'),
#  (8, 'Meena Iyer', 'Finance'),
#  (9, 'Suresh Babu', 'IT'),
#  (10, 'Anjali Gupta', 'Marketing'),
#  (12, 'Kavya Menon', 'IT'),
#  (13, 'Ajay Patel', 'Finance'),
#  (15, 'Naveen Kumar', 'IT'),
#  (16, 'Aishwarya Rao', 'Marketing'),
#  (18, 'Neha Agarwal', 'Finance'),
#  (19, 'Harish Kumar', 'IT'),
#  (22, 'Lakshmi Priya', 'Marketing'),
#  (23, 'Ramesh Krishnan', 'IT'),
#  (24, 'Nisha Kapoor', 'Finance'),
#  (26, 'Keerthana S', 'IT'),
#  (29, 'Bhavya Jain', 'Finance'),
#  (30, 'Mohit Arora', 'IT'),
#  (33, 'Swathi K', 'Marketing'),
#  (34, 'Gokul N', 'IT'),
#  (35, 'Ashok Pillai', 'Finance'),
#  (38, 'Reshma Ali', 'Marketing'),
#  (39, 'Dinesh Kumar', 'IT'),
#  (40, 'Farhan Khan', 'Finance'),
#  (43, 'Abhishek Roy', 'Marketing'),
#  (44, 'Geetha S', 'IT'),
#  (45, 'Vasanth Kumar', 'Finance'),
#  (48, 'Harini V', 'Marketing'),
# ...

# %% [markdown]
# ---

# %% [markdown]
# # 3. Temporary Table
#
# **Definition:**
#
# A **Temporary Table** is used to store data temporarily. The table exists only for the duration of the current database session and is automatically removed when the session ends.
#
# For example, if you create a temporary table in **Jupyter Notebook**, it will only be available in that Jupyter SQL session. It will **not** be visible in another session, such as **MySQL Workbench**.
#
# ## Syntax
#
# ```sql
# CREATE TEMPORARY TABLE table_name (
#     column1 datatype,
#     column2 datatype,
#     column3 datatype
# );
# ```
#
# ## Example
#
# ```sql
# CREATE TEMPORARY TABLE temp_employees (
#     emp_id INT,
#     emp_name VARCHAR(100),
#     department VARCHAR(50)
# );
# ```
#
# ## Temporary Table Using CTAS
#
# A temporary table can also be created using **CTAS (Create Table As Select)**.
#
# ### Copy All Records
#
# ```sql
# CREATE TEMPORARY TABLE temp_employees AS
# SELECT *
# FROM employees_day;
# ```
#
# ### Copy Only Specific Columns
#
# ```sql
# CREATE TEMPORARY TABLE temp_employee_details AS
# SELECT emp_id, emp_name, department
# FROM employees_day;
# ```
#
# ### Copy Only Specific Rows
#
# ```sql
# CREATE TEMPORARY TABLE temp_it_employees AS
# SELECT *
# FROM employees_day
# WHERE department = 'IT';
# ```
#
# ## Verify the Temporary Table
#
# ```sql
# SELECT * FROM temp_employees;
# ```

# %%
# %%sql
# -- One Example
# CREATE TEMPORARY TABLE temp_it_employees as
# SELECT *
# FROM employees_day
# WHERE department = 'IT';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 13 rows affected.
# []

# %%
# %%sql
# SELECT * FROM temp_it_employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 13 rows affected.
# [(1, 'Arun Kumar', 'IT', Decimal('45000.00')),
#  (6, 'Divya Nair', 'IT', Decimal('62000.00')),
#  (9, 'Suresh Babu', 'IT', Decimal('61000.00')),
#  (12, 'Kavya Menon', 'IT', Decimal('68000.00')),
#  (15, 'Naveen Kumar', 'IT', Decimal('59000.00')),
#  (19, 'Harish Kumar', 'IT', Decimal('72000.00')),
#  (23, 'Ramesh Krishnan', 'IT', Decimal('67000.00')),
#  (26, 'Keerthana S', 'IT', Decimal('63000.00')),
#  (30, 'Mohit Arora', 'IT', Decimal('70000.00')),
#  (34, 'Gokul N', 'IT', Decimal('65000.00')),
#  (39, 'Dinesh Kumar', 'IT', Decimal('69000.00')),
#  (44, 'Geetha S', 'IT', Decimal('64000.00')),
#  (49, 'Surya Narayanan', 'IT', Decimal('75000.00'))]

# %% [markdown]
# ---

# %% [markdown]
# # 4. Common Table Expression (CTE)
#
# **Definition:**
#
# A **Common Table Expression (CTE)** is a **temporary result set** that is defined within a SQL query and can be referenced like a **virtual table**. It exists only during the execution of that query. CTEs make complex SQL queries **easier to read, write, and maintain** by breaking them into smaller, logical parts.
#
# ---
#
# ## Syntax
#
# ```sql
# WITH cte_name AS (
#     SELECT column1, column2, ...
#     FROM table_name
#     WHERE condition
# )
# SELECT *
# FROM cte_name;
# ```
#
# ---
#
# ## Execution Flow
#
# When a CTE is executed, SQL processes it in the following order:
#
# 1. The query inside the `WITH` clause executes first.
# 2. The result of that query is stored as a **temporary result set** (virtual table).
# 3. The main query uses the CTE just like a normal table.
# 4. Once the query execution is completed, the CTE is automatically removed.
#
# ---
#
# ## Example
#
# ```sql
# WITH high_salary_employees AS (
#     SELECT *
#     FROM employees_day
#     WHERE salary > 50000
# )
#
# SELECT *
# FROM high_salary_employees;
# ```
#
# In the above example:
#
# - The query inside the `WITH` clause executes first.
# - The filtered records are stored in the temporary result set named `high_salary_employees`.
# - The `SELECT` statement retrieves data from the CTE.
# - After the query finishes, the CTE no longer exists.
#
#
#
# ## Example: Using CTE with CTAS
#
# A **CTE** can also be combined with **CTAS (Create Table As Select)** to create a new table from the CTE result.
#
# ```sql
# %%sql
# CREATE TABLE bonus_table AS
# WITH bonus_cte AS (
#     SELECT
#         emp_id,
#         emp_name,
#         department,
#         salary,
#         salary * 0.30 AS bonus_salary
#     FROM employees_day
# )
# SELECT *
# FROM bonus_cte;
# ```
#
# ### Execution Flow
#
# 1. The query inside `bonus_cte` executes first.
# 2. A temporary result set is created with the calculated `bonus_salary` column.
# 3. The `SELECT * FROM bonus_cte` statement reads the data from the CTE.
# 4. `CREATE TABLE bonus_table AS` stores the final result permanently in the `bonus_table`.
# 5. After the execution is completed, the CTE `bonus_cte` is automatically removed, while `bonus_table` remains in the database.

# %%
# %%sql
# -- Example  1 : Create a CTE and store and select the data
# WITH bonus_cte AS (
#     SELECT emp_name, salary * 0.2 as bonus_amount
#     from employees_day
# )
# select * from bonus_cte;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 50 rows affected.
# [('Arun Kumar', Decimal('9000.000')),
#  ('Priya Sharma', Decimal('8400.000')),
#  ('Karthik Raj', Decimal('11000.000')),
#  ('Sneha Reddy', Decimal('9600.000')),
#  ('Rahul Verma', Decimal('9400.000')),
#  ('Divya Nair', Decimal('12400.000')),
#  ('Vikram Singh', Decimal('7800.000')),
#  ('Meena Iyer', Decimal('10600.000')),
#  ('Suresh Babu', Decimal('12200.000')),
#  ('Anjali Gupta', Decimal('10000.000')),
#  ('Rohit Das', Decimal('8800.000')),
#  ('Kavya Menon', Decimal('13600.000')),
#  ('Ajay Patel', Decimal('11400.000')),
#  ('Pooja Mishra', Decimal('8200.000')),
#  ('Naveen Kumar', Decimal('11800.000')),
#  ('Aishwarya Rao', Decimal('10200.000')),
#  ('Manoj Kumar', Decimal('9200.000')),
#  ('Neha Agarwal', Decimal('11200.000')),
#  ('Harish Kumar', Decimal('14400.000')),
#  ('Shalini Devi', Decimal('8600.000')),
#  ('Deepak Joshi', Decimal('9000.000')),
#  ('Lakshmi Priya', Decimal('10400.000')),
# ...

# %%
# %%sql
# CREATE TABLE bonus_table as
# with bonus_cte as (
#     SELECT emp_id,emp_name,department,salary,salary * 0.3 as bonus_salary
#     FROM employees_day
# )
# select * from bonus_cte;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 50 rows affected.
# []

# %% [markdown]
# # ALTER Statement
#
# **Definition:**
#
# The `ALTER` statement is used to modify the structure of an existing database object without deleting it. It allows you to make changes to both **tables** and **columns**.
#
# Using `ALTER`, you can:
# - Add new columns.
# - Modify existing columns.
# - Rename columns.
# - Drop columns.
# - Rename tables.
#
# ---

# %% [markdown]
# # 1. Add a New Column
#
# ## Syntax
#
# ```sql
# ALTER TABLE table_name
# ADD COLUMN column_name datatype;
# ```
#
# ## Example
#
# ```sql
# ALTER TABLE employees_day
# ADD COLUMN email VARCHAR(100);
# ```
#
# ---

# %%
# %%sql
# desc employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [('emp_id', 'int', 'YES', '', None, ''),
#  ('emp_name', 'varchar(100)', 'YES', '', None, ''),
#  ('department', 'varchar(50)', 'YES', '', None, ''),
#  ('salary', 'decimal(10,2)', 'YES', '', None, '')]

# %%
# %%sql
# ALTER TABLE employees
# ADD COLUMN gender varchar(10);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# desc employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [('emp_id', 'int', 'YES', '', None, ''),
#  ('emp_name', 'varchar(100)', 'YES', '', None, ''),
#  ('department', 'varchar(50)', 'YES', '', None, ''),
#  ('salary', 'decimal(10,2)', 'YES', '', None, ''),
#  ('gender', 'varchar(10)', 'YES', '', None, '')]

# %%
# %%sql
# -- add column with default values
# ALTER TABLE employees
# ADD COLUMN dept varchar(10) DEFAULT 'IT';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# desc employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 6 rows affected.
# [('emp_id', 'int', 'YES', '', None, ''),
#  ('emp_name', 'varchar(100)', 'YES', '', None, ''),
#  ('department', 'varchar(50)', 'YES', '', None, ''),
#  ('salary', 'decimal(10,2)', 'YES', '', None, ''),
#  ('gender', 'varchar(100)', 'YES', '', None, ''),
#  ('departments', 'varchar(10)', 'YES', '', 'IT', '')]

# %%
# %%sql
# -- add multiple columns
# ALTER TABLE tp_employees
# ADD area varchar(100),
# ADD age int;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # 2. Modify a Column
#
# ## Syntax
#
# ```sql
# ALTER TABLE table_name
# MODIFY COLUMN column_name new_datatype;
# ```
#
# ## Example
#
# ```sql
# ALTER TABLE employees_day
# MODIFY COLUMN emp_name VARCHAR(150);
# ```
#
# ---

# %%
# %%sql
# ALTER TABLE employees
# MODIFY COLUMN gender varchar(100);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # 3. Rename a Column
#
# ## Syntax
#
# ```sql
# ALTER TABLE table_name
# RENAME COLUMN old_column_name TO new_column_name;
# ```
#
# ## Example
#
# ```sql
# ALTER TABLE employees_day
# RENAME COLUMN emp_name TO employee_name;
# ```
#
# ---

# %%
# %%sql
# ALTER TABLE employees
# RENAME COLUMN department to emp_dept;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # 4. Drop a Column
#
# ## Syntax
#
# ```sql
# ALTER TABLE table_name
# DROP COLUMN column_name;
# ```
#
# ## Example
#
# ```sql
# ALTER TABLE employees_day
# DROP COLUMN email;
# ```
#
# ---

# %%
# %%sql
# ALTER TABLE employees
# DROP COLUMN departments;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # 5. Rename a Table
#
# ## Syntax
#
# ```sql
# ALTER TABLE old_table_name
# RENAME TO new_table_name;
# ```
#
# ## Example
#
# ```sql
# ALTER TABLE employees_day
# RENAME TO employees;
# ```

# %%
# %%sql
# ALTER TABLE employees
# RENAME TO tp_employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # WHERE Clause
#
# **Definition:**
#
# The `WHERE` clause is used to **filter records** based on one or more conditions. It returns only the rows that satisfy the specified condition.
#
# ---
#
# ## Syntax
#
# ```sql
# SELECT column_name(s)
# FROM table_name
# WHERE condition;
# ```
#
# ---

# %% [markdown]
# # 1. Equal To (`=`)
#
# **Definition:**
#
# Returns rows where the specified column value is equal to the given value.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE department = 'IT';
# ```
#
# ---

# %%
# %%sql
# SELECT * from employees_day
# WHERE department = 'IT';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 13 rows affected.
# [(1, 'Arun Kumar', 'IT', Decimal('45000.00')),
#  (6, 'Divya Nair', 'IT', Decimal('62000.00')),
#  (9, 'Suresh Babu', 'IT', Decimal('61000.00')),
#  (12, 'Kavya Menon', 'IT', Decimal('68000.00')),
#  (15, 'Naveen Kumar', 'IT', Decimal('59000.00')),
#  (19, 'Harish Kumar', 'IT', Decimal('72000.00')),
#  (23, 'Ramesh Krishnan', 'IT', Decimal('67000.00')),
#  (26, 'Keerthana S', 'IT', Decimal('63000.00')),
#  (30, 'Mohit Arora', 'IT', Decimal('70000.00')),
#  (34, 'Gokul N', 'IT', Decimal('65000.00')),
#  (39, 'Dinesh Kumar', 'IT', Decimal('69000.00')),
#  (44, 'Geetha S', 'IT', Decimal('64000.00')),
#  (49, 'Surya Narayanan', 'IT', Decimal('75000.00'))]

# %% [markdown]
# # 2. Greater Than (`>`)
#
# **Definition:**
#
# Returns rows where the column value is greater than the specified value.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE salary > 50000;
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE salary > 70000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(19, 'Harish Kumar', 'IT', Decimal('72000.00')),
#  (49, 'Surya Narayanan', 'IT', Decimal('75000.00'))]

# %% [markdown]
# # 3. Less Than (`<`)
#
# **Definition:**
#
# Returns rows where the column value is less than the specified value.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE salary < 50000;
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE salary < 70000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 47 rows affected.
# [(1, 'Arun Kumar', 'IT', Decimal('45000.00')),
#  (2, 'Priya Sharma', 'HR', Decimal('42000.00')),
#  (3, 'Karthik Raj', 'Finance', Decimal('55000.00')),
#  (4, 'Sneha Reddy', 'Marketing', Decimal('48000.00')),
#  (5, 'Rahul Verma', 'Sales', Decimal('47000.00')),
#  (6, 'Divya Nair', 'IT', Decimal('62000.00')),
#  (7, 'Vikram Singh', 'HR', Decimal('39000.00')),
#  (8, 'Meena Iyer', 'Finance', Decimal('53000.00')),
#  (9, 'Suresh Babu', 'IT', Decimal('61000.00')),
#  (10, 'Anjali Gupta', 'Marketing', Decimal('50000.00')),
#  (11, 'Rohit Das', 'Sales', Decimal('44000.00')),
#  (12, 'Kavya Menon', 'IT', Decimal('68000.00')),
#  (13, 'Ajay Patel', 'Finance', Decimal('57000.00')),
#  (14, 'Pooja Mishra', 'HR', Decimal('41000.00')),
#  (15, 'Naveen Kumar', 'IT', Decimal('59000.00')),
#  (16, 'Aishwarya Rao', 'Marketing', Decimal('51000.00')),
#  (17, 'Manoj Kumar', 'Sales', Decimal('46000.00')),
# ...

# %% [markdown]
# # 4. Greater Than or Equal To (`>=`)
#
# **Definition:**
#
# Returns rows where the column value is greater than or equal to the specified value.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE salary >= 50000;
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE salary >= 70000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(19, 'Harish Kumar', 'IT', Decimal('72000.00')),
#  (30, 'Mohit Arora', 'IT', Decimal('70000.00')),
#  (49, 'Surya Narayanan', 'IT', Decimal('75000.00'))]

# %% [markdown]
# # 5. Less Than or Equal To (`<=`)
#
# **Definition:**
#
# Returns rows where the column value is less than or equal to the specified value.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE salary <= 50000;
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE salary <= 45000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 12 rows affected.
# [(1, 'Arun Kumar', 'IT', Decimal('45000.00')),
#  (2, 'Priya Sharma', 'HR', Decimal('42000.00')),
#  (7, 'Vikram Singh', 'HR', Decimal('39000.00')),
#  (11, 'Rohit Das', 'Sales', Decimal('44000.00')),
#  (14, 'Pooja Mishra', 'HR', Decimal('41000.00')),
#  (20, 'Shalini Devi', 'HR', Decimal('43000.00')),
#  (21, 'Deepak Joshi', 'Sales', Decimal('45000.00')),
#  (25, 'Ganesh R', 'HR', Decimal('40000.00')),
#  (31, 'Anitha P', 'HR', Decimal('42500.00')),
#  (36, 'Sonia Thomas', 'HR', Decimal('41500.00')),
#  (41, 'Preethi R', 'HR', Decimal('43500.00')),
#  (46, 'Komal Shah', 'HR', Decimal('44500.00'))]

# %% [markdown]
# # 6. Not Equal To (`!=` or `<>`)
#
# **Definition:**
#
# Returns rows where the column value is not equal to the specified value.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE department != 'IT';
# ```
#
# or
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE department <> 'IT';
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE department != 'IT';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 37 rows affected.
# [(2, 'Priya Sharma', 'HR', Decimal('42000.00')),
#  (3, 'Karthik Raj', 'Finance', Decimal('55000.00')),
#  (4, 'Sneha Reddy', 'Marketing', Decimal('48000.00')),
#  (5, 'Rahul Verma', 'Sales', Decimal('47000.00')),
#  (7, 'Vikram Singh', 'HR', Decimal('39000.00')),
#  (8, 'Meena Iyer', 'Finance', Decimal('53000.00')),
#  (10, 'Anjali Gupta', 'Marketing', Decimal('50000.00')),
#  (11, 'Rohit Das', 'Sales', Decimal('44000.00')),
#  (13, 'Ajay Patel', 'Finance', Decimal('57000.00')),
#  (14, 'Pooja Mishra', 'HR', Decimal('41000.00')),
#  (16, 'Aishwarya Rao', 'Marketing', Decimal('51000.00')),
#  (17, 'Manoj Kumar', 'Sales', Decimal('46000.00')),
#  (18, 'Neha Agarwal', 'Finance', Decimal('56000.00')),
#  (20, 'Shalini Devi', 'HR', Decimal('43000.00')),
#  (21, 'Deepak Joshi', 'Sales', Decimal('45000.00')),
#  (22, 'Lakshmi Priya', 'Marketing', Decimal('52000.00')),
# ...

# %% [markdown]
# # 7. AND Operator
#
# **Definition:**
#
# The `AND` operator returns rows only when **all** specified conditions are true.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE department = 'IT'
# AND salary > 50000;
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE department = 'IT'
# AND salary > 50000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 12 rows affected.
# [(6, 'Divya Nair', 'IT', Decimal('62000.00')),
#  (9, 'Suresh Babu', 'IT', Decimal('61000.00')),
#  (12, 'Kavya Menon', 'IT', Decimal('68000.00')),
#  (15, 'Naveen Kumar', 'IT', Decimal('59000.00')),
#  (19, 'Harish Kumar', 'IT', Decimal('72000.00')),
#  (23, 'Ramesh Krishnan', 'IT', Decimal('67000.00')),
#  (26, 'Keerthana S', 'IT', Decimal('63000.00')),
#  (30, 'Mohit Arora', 'IT', Decimal('70000.00')),
#  (34, 'Gokul N', 'IT', Decimal('65000.00')),
#  (39, 'Dinesh Kumar', 'IT', Decimal('69000.00')),
#  (44, 'Geetha S', 'IT', Decimal('64000.00')),
#  (49, 'Surya Narayanan', 'IT', Decimal('75000.00'))]

# %% [markdown]
# # 8. OR Operator
#
# **Definition:**
#
# The `OR` operator returns rows when **at least one** of the specified conditions is true.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE department = 'IT'
# OR department = 'HR';
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE department = 'IT'
# OR department = 'HR';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 22 rows affected.
# [(1, 'Arun Kumar', 'IT', Decimal('45000.00')),
#  (2, 'Priya Sharma', 'HR', Decimal('42000.00')),
#  (6, 'Divya Nair', 'IT', Decimal('62000.00')),
#  (7, 'Vikram Singh', 'HR', Decimal('39000.00')),
#  (9, 'Suresh Babu', 'IT', Decimal('61000.00')),
#  (12, 'Kavya Menon', 'IT', Decimal('68000.00')),
#  (14, 'Pooja Mishra', 'HR', Decimal('41000.00')),
#  (15, 'Naveen Kumar', 'IT', Decimal('59000.00')),
#  (19, 'Harish Kumar', 'IT', Decimal('72000.00')),
#  (20, 'Shalini Devi', 'HR', Decimal('43000.00')),
#  (23, 'Ramesh Krishnan', 'IT', Decimal('67000.00')),
#  (25, 'Ganesh R', 'HR', Decimal('40000.00')),
#  (26, 'Keerthana S', 'IT', Decimal('63000.00')),
#  (30, 'Mohit Arora', 'IT', Decimal('70000.00')),
#  (31, 'Anitha P', 'HR', Decimal('42500.00')),
#  (34, 'Gokul N', 'IT', Decimal('65000.00')),
#  (36, 'Sonia Thomas', 'HR', Decimal('41500.00')),
#  (39, 'Dinesh Kumar', 'IT', Decimal('69000.00')),
# ...

# %% [markdown]
# # 9. NOT Operator
#
# **Definition:**
#
# The `NOT` operator reverses the result of a condition.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE NOT department = 'IT';
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE NOT department = 'IT';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 37 rows affected.
# [(2, 'Priya Sharma', 'HR', Decimal('42000.00')),
#  (3, 'Karthik Raj', 'Finance', Decimal('55000.00')),
#  (4, 'Sneha Reddy', 'Marketing', Decimal('48000.00')),
#  (5, 'Rahul Verma', 'Sales', Decimal('47000.00')),
#  (7, 'Vikram Singh', 'HR', Decimal('39000.00')),
#  (8, 'Meena Iyer', 'Finance', Decimal('53000.00')),
#  (10, 'Anjali Gupta', 'Marketing', Decimal('50000.00')),
#  (11, 'Rohit Das', 'Sales', Decimal('44000.00')),
#  (13, 'Ajay Patel', 'Finance', Decimal('57000.00')),
#  (14, 'Pooja Mishra', 'HR', Decimal('41000.00')),
#  (16, 'Aishwarya Rao', 'Marketing', Decimal('51000.00')),
#  (17, 'Manoj Kumar', 'Sales', Decimal('46000.00')),
#  (18, 'Neha Agarwal', 'Finance', Decimal('56000.00')),
#  (20, 'Shalini Devi', 'HR', Decimal('43000.00')),
#  (21, 'Deepak Joshi', 'Sales', Decimal('45000.00')),
#  (22, 'Lakshmi Priya', 'Marketing', Decimal('52000.00')),
# ...

# %% [markdown]
# # 10. BETWEEN
#
# **Definition:**
#
# The `BETWEEN` operator returns rows where the column value falls within the specified range (inclusive).
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE salary BETWEEN 40000 AND 60000;
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE salary BETWEEN 40000 AND 60000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 36 rows affected.
# [(1, 'Arun Kumar', 'IT', Decimal('45000.00')),
#  (2, 'Priya Sharma', 'HR', Decimal('42000.00')),
#  (3, 'Karthik Raj', 'Finance', Decimal('55000.00')),
#  (4, 'Sneha Reddy', 'Marketing', Decimal('48000.00')),
#  (5, 'Rahul Verma', 'Sales', Decimal('47000.00')),
#  (8, 'Meena Iyer', 'Finance', Decimal('53000.00')),
#  (10, 'Anjali Gupta', 'Marketing', Decimal('50000.00')),
#  (11, 'Rohit Das', 'Sales', Decimal('44000.00')),
#  (13, 'Ajay Patel', 'Finance', Decimal('57000.00')),
#  (14, 'Pooja Mishra', 'HR', Decimal('41000.00')),
#  (15, 'Naveen Kumar', 'IT', Decimal('59000.00')),
#  (16, 'Aishwarya Rao', 'Marketing', Decimal('51000.00')),
#  (17, 'Manoj Kumar', 'Sales', Decimal('46000.00')),
#  (18, 'Neha Agarwal', 'Finance', Decimal('56000.00')),
#  (20, 'Shalini Devi', 'HR', Decimal('43000.00')),
#  (21, 'Deepak Joshi', 'Sales', Decimal('45000.00')),
#  (22, 'Lakshmi Priya', 'Marketing', Decimal('52000.00')),
# ...

# %% [markdown]
# # 11. IN
#
# **Definition:**
#
# The `IN` operator returns rows where the column value matches any value in the specified list.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE department IN ('IT', 'HR', 'Finance');
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE department IN ('IT', 'HR', 'Finance');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 32 rows affected.
# [(1, 'Arun Kumar', 'IT', Decimal('45000.00')),
#  (2, 'Priya Sharma', 'HR', Decimal('42000.00')),
#  (3, 'Karthik Raj', 'Finance', Decimal('55000.00')),
#  (6, 'Divya Nair', 'IT', Decimal('62000.00')),
#  (7, 'Vikram Singh', 'HR', Decimal('39000.00')),
#  (8, 'Meena Iyer', 'Finance', Decimal('53000.00')),
#  (9, 'Suresh Babu', 'IT', Decimal('61000.00')),
#  (12, 'Kavya Menon', 'IT', Decimal('68000.00')),
#  (13, 'Ajay Patel', 'Finance', Decimal('57000.00')),
#  (14, 'Pooja Mishra', 'HR', Decimal('41000.00')),
#  (15, 'Naveen Kumar', 'IT', Decimal('59000.00')),
#  (18, 'Neha Agarwal', 'Finance', Decimal('56000.00')),
#  (19, 'Harish Kumar', 'IT', Decimal('72000.00')),
#  (20, 'Shalini Devi', 'HR', Decimal('43000.00')),
#  (23, 'Ramesh Krishnan', 'IT', Decimal('67000.00')),
#  (24, 'Nisha Kapoor', 'Finance', Decimal('54000.00')),
#  (25, 'Ganesh R', 'HR', Decimal('40000.00')),
# ...

# %% [markdown]
# # 12. NOT IN
#
# **Definition:**
#
# The `NOT IN` operator returns rows where the column value does not match any value in the specified list.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE department NOT IN ('IT', 'HR');
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE department NOT IN ('IT', 'HR');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 28 rows affected.
# [(3, 'Karthik Raj', 'Finance', Decimal('55000.00')),
#  (4, 'Sneha Reddy', 'Marketing', Decimal('48000.00')),
#  (5, 'Rahul Verma', 'Sales', Decimal('47000.00')),
#  (8, 'Meena Iyer', 'Finance', Decimal('53000.00')),
#  (10, 'Anjali Gupta', 'Marketing', Decimal('50000.00')),
#  (11, 'Rohit Das', 'Sales', Decimal('44000.00')),
#  (13, 'Ajay Patel', 'Finance', Decimal('57000.00')),
#  (16, 'Aishwarya Rao', 'Marketing', Decimal('51000.00')),
#  (17, 'Manoj Kumar', 'Sales', Decimal('46000.00')),
#  (18, 'Neha Agarwal', 'Finance', Decimal('56000.00')),
#  (21, 'Deepak Joshi', 'Sales', Decimal('45000.00')),
#  (22, 'Lakshmi Priya', 'Marketing', Decimal('52000.00')),
#  (24, 'Nisha Kapoor', 'Finance', Decimal('54000.00')),
#  (27, 'Prakash M', 'Marketing', Decimal('49000.00')),
#  (28, 'Sanjay Yadav', 'Sales', Decimal('47000.00')),
#  (29, 'Bhavya Jain', 'Finance', Decimal('58000.00')),
# ...

# %% [markdown]
# # 13. LIKE
#
# **Definition:**
#
# The `LIKE` operator is used to search for a specific pattern in a column.
#
# ### Common Wildcards
#
# - `%` → Represents zero or more characters.
# - `_` → Represents exactly one character.

# %% [markdown]
# ## Example 1: Starts With
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE emp_name LIKE 'A%';
# ```

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE emp_name LIKE 'A%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# 1 rows affected.
# [(29, 'Bhavya Jain', 'Finance', Decimal('58000.00'))]

# %% [markdown]
# ## Example 2: Ends With
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE emp_name LIKE '%n';
# ```

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE emp_name LIKE '%n';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 6 rows affected.
# [(12, 'Kavya Menon', 'IT', Decimal('68000.00')),
#  (23, 'Ramesh Krishnan', 'IT', Decimal('67000.00')),
#  (29, 'Bhavya Jain', 'Finance', Decimal('58000.00')),
#  (34, 'Gokul N', 'IT', Decimal('65000.00')),
#  (40, 'Farhan Khan', 'Finance', Decimal('61000.00')),
#  (49, 'Surya Narayanan', 'IT', Decimal('75000.00'))]

# %% [markdown]
# ## Example 3: Contains
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE emp_name LIKE '%ar%';

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE emp_name LIKE '%ar%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 15 rows affected.
# [(1, 'Arun Kumar', 'IT', Decimal('45000.00')),
#  (2, 'Priya Sharma', 'HR', Decimal('42000.00')),
#  (3, 'Karthik Raj', 'Finance', Decimal('55000.00')),
#  (15, 'Naveen Kumar', 'IT', Decimal('59000.00')),
#  (16, 'Aishwarya Rao', 'Marketing', Decimal('51000.00')),
#  (17, 'Manoj Kumar', 'Sales', Decimal('46000.00')),
#  (18, 'Neha Agarwal', 'Finance', Decimal('56000.00')),
#  (19, 'Harish Kumar', 'IT', Decimal('72000.00')),
#  (30, 'Mohit Arora', 'IT', Decimal('70000.00')),
#  (39, 'Dinesh Kumar', 'IT', Decimal('69000.00')),
#  (40, 'Farhan Khan', 'Finance', Decimal('61000.00')),
#  (42, 'Nitin Sharma', 'Sales', Decimal('47500.00')),
#  (45, 'Vasanth Kumar', 'Finance', Decimal('59000.00')),
#  (48, 'Harini V', 'Marketing', Decimal('53500.00')),
#  (49, 'Surya Narayanan', 'IT', Decimal('75000.00'))]

# %% [markdown]
# ## Example 4: Single Character Wildcard
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE emp_name LIKE '_a%';
# ```
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE emp_name LIKE '_a%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 14 rows affected.
# [(3, 'Karthik Raj', 'Finance', Decimal('55000.00')),
#  (5, 'Rahul Verma', 'Sales', Decimal('47000.00')),
#  (12, 'Kavya Menon', 'IT', Decimal('68000.00')),
#  (15, 'Naveen Kumar', 'IT', Decimal('59000.00')),
#  (17, 'Manoj Kumar', 'Sales', Decimal('46000.00')),
#  (19, 'Harish Kumar', 'IT', Decimal('72000.00')),
#  (22, 'Lakshmi Priya', 'Marketing', Decimal('52000.00')),
#  (23, 'Ramesh Krishnan', 'IT', Decimal('67000.00')),
#  (25, 'Ganesh R', 'HR', Decimal('40000.00')),
#  (28, 'Sanjay Yadav', 'Sales', Decimal('47000.00')),
#  (32, 'Ravi Teja', 'Sales', Decimal('45500.00')),
#  (40, 'Farhan Khan', 'Finance', Decimal('61000.00')),
#  (45, 'Vasanth Kumar', 'Finance', Decimal('59000.00')),
#  (48, 'Harini V', 'Marketing', Decimal('53500.00'))]

# %% [markdown]
# # 14. IS NULL
#
# **Definition:**
#
# The `IS NULL` operator returns rows where the specified column contains a `NULL` value.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE department IS NULL;
# ```
#
#
# ---

# %%
# %%sql
# SELECT *
# FROM employees_day
# WHERE department IS NULL;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # 15. IS NOT NULL
#
# **Definition:**
#
# The `IS NOT NULL` operator returns rows where the specified column does not contain a `NULL` value.
#
# ## Example
#
# ```sql
# SELECT *
# FROM employees_day
# WHERE department IS NOT NULL;
# ```

# %%
# %%sql
# SELECT * FROM employees_day
# WHERE department IS NOT NULL;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 50 rows affected.
# [(1, 'Arun Kumar', 'IT', Decimal('45000.00')),
#  (2, 'Priya Sharma', 'HR', Decimal('42000.00')),
#  (3, 'Karthik Raj', 'Finance', Decimal('55000.00')),
#  (4, 'Sneha Reddy', 'Marketing', Decimal('48000.00')),
#  (5, 'Rahul Verma', 'Sales', Decimal('47000.00')),
#  (6, 'Divya Nair', 'IT', Decimal('62000.00')),
#  (7, 'Vikram Singh', 'HR', Decimal('39000.00')),
#  (8, 'Meena Iyer', 'Finance', Decimal('53000.00')),
#  (9, 'Suresh Babu', 'IT', Decimal('61000.00')),
#  (10, 'Anjali Gupta', 'Marketing', Decimal('50000.00')),
#  (11, 'Rohit Das', 'Sales', Decimal('44000.00')),
#  (12, 'Kavya Menon', 'IT', Decimal('68000.00')),
#  (13, 'Ajay Patel', 'Finance', Decimal('57000.00')),
#  (14, 'Pooja Mishra', 'HR', Decimal('41000.00')),
#  (15, 'Naveen Kumar', 'IT', Decimal('59000.00')),
#  (16, 'Aishwarya Rao', 'Marketing', Decimal('51000.00')),
#  (17, 'Manoj Kumar', 'Sales', Decimal('46000.00')),
# ...

# %% [markdown]
# # SQL Query Execution Order
#
# Although we write SQL queries in one order, the **SQL engine executes them in a different order**. Understanding the execution order helps in writing efficient and error-free queries.
#
# ---
#
# ## Example Query
#
# ```sql
# SELECT department, AVG(salary) AS avg_salary
# FROM employees_day
# WHERE salary > 30000
# GROUP BY department
# HAVING AVG(salary) > 50000
# ORDER BY avg_salary DESC
# LIMIT 5;
# ```
#
# ---
#
# # Actual Execution Order
#
# ## 1. FROM
#
# **Purpose:**
#
# Identifies the table(s) from which the data should be retrieved.
#
# ```sql
# FROM employees_day
# ```
#
# At this stage, SQL reads all the records from the `employees_day` table.
#
# ---
#
# ## 2. WHERE
#
# **Purpose:**
#
# Filters individual rows before any grouping or aggregation takes place.
#
# ```sql
# WHERE salary > 30000
# ```
#
# Only employees with a salary greater than **30,000** are considered for the next steps.
#
# ---
#
# ## 3. GROUP BY
#
# **Purpose:**
#
# Groups rows that have the same value in the specified column.
#
# ```sql
# GROUP BY department
# ```
#
# All employees are grouped according to their department.
#
# ---
#
# ## 4. HAVING
#
# **Purpose:**
#
# Filters the grouped data after the aggregation is performed.
#
# ```sql
# HAVING AVG(salary) > 50000
# ```
#
# Only departments with an average salary greater than **50,000** are retained.
#
# ---
#
# ## 5. SELECT
#
# **Purpose:**
#
# Chooses the columns and expressions that will appear in the final output.
#
# ```sql
# SELECT department,
#        AVG(salary) AS avg_salary
# ```
#
# The average salary is calculated for each remaining department.
#
# ---
#
# ## 6. ORDER BY
#
# **Purpose:**
#
# Sorts the final result set.
#
# ```sql
# ORDER BY avg_salary DESC
# ```
#
# The departments are sorted in descending order of average salary.
#
# ---
#
# ## 7. LIMIT
#
# **Purpose:**
#
# Restricts the number of rows returned.
#
# ```sql
# LIMIT 5;
# ```
#
# Only the first **5** rows from the sorted result are displayed.
#
# ---
#
# # Complete Execution Flow
#
# ```
# FROM
#    ↓
# WHERE
#    ↓
# GROUP BY
#    ↓
# HAVING
#    ↓
# SELECT
#    ↓
# ORDER BY
#    ↓
# LIMIT
# ```
#
# ---
#
# # Easy Way to Remember
#
# | Execution Order | Clause | Purpose |
# |----------------:|---------|---------|
# | 1 | `FROM` | Reads the table(s). |
# | 2 | `WHERE` | Filters rows. |
# | 3 | `GROUP BY` | Creates groups. |
# | 4 | `HAVING` | Filters groups. |
# | 5 | `SELECT` | Chooses columns and expressions. |
# | 6 | `ORDER BY` | Sorts the result. |
# | 7 | `LIMIT` | Restricts the number of rows returned. |

# %% [markdown]
# # Constraints
#
# **Definition:**
#
# **Constraints** are rules applied to table columns to enforce data integrity, accuracy, and consistency in a database. They help ensure that only valid data is stored in the table.
#
# Some of the commonly used SQL constraints are:
#
# - Primary Key
# - Foreign Key
# - Unique
# - Not Null
# - Check
# - Default
#
# ---
#
# # 1. PRIMARY KEY
#
# **Definition:**
#
# A **Primary Key** is a column (or a combination of columns) that uniquely identifies each record in a table. A primary key **cannot contain `NULL` values** and **duplicate values are not allowed**.
#
# ## Characteristics
#
# - Uniquely identifies each row.
# - Does not allow duplicate values.
# - Does not allow `NULL` values.
# - A table can have **only one Primary Key**.
# - A Primary Key can consist of one or more columns (Composite Primary Key).
#
# ---
#
# ## Syntax
#
# ```sql
# CREATE TABLE table_name (
#     column_name datatype PRIMARY KEY,
#     column2 datatype,
#     column3 datatype
# );
# ```
#
# ---
#
# ## Example
#
# ```sql
# CREATE TABLE employees (
#     emp_id INT PRIMARY KEY,
#     emp_name VARCHAR(100),
#     department VARCHAR(50),
#     salary DECIMAL(10,2)
# );
# ```
#
# ---
#
# ## Adding a Primary Key Using ALTER
#
# ### Syntax
#
# ```sql
# ALTER TABLE table_name
# ADD PRIMARY KEY (column_name);
# ```
#
# ### Example
#
# ```sql
# ALTER TABLE employees
# ADD PRIMARY KEY (emp_id);
# ```

# %%
# %%sql
# ALTER TABLE tp_employees
# ADD PRIMARY KEY (emp_id);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# desc tp_employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [('emp_id', 'int', 'NO', 'PRI', None, ''),
#  ('emp_name', 'varchar(100)', 'YES', '', None, ''),
#  ('emp_dept', 'varchar(50)', 'YES', '', None, ''),
#  ('salary', 'decimal(10,2)', 'YES', '', None, ''),
#  ('gender', 'varchar(100)', 'YES', '', None, ''),
#  ('area', 'varchar(100)', 'YES', '', None, ''),
#  ('age', 'int', 'YES', '', None, '')]

# %% [markdown]
# ## Composite Primary Key
#
# A **Composite Primary Key** is a primary key created using **two or more columns**.
#
# ### Syntax
#
# ```sql
# CREATE TABLE table_name (
#     column1 datatype,
#     column2 datatype,
#     column3 datatype,
#     PRIMARY KEY (column1, column2)
# );
# ```
#
# ### Example
#
# ```sql
# CREATE TABLE employee_projects (
#     emp_id INT,
#     project_id INT,
#     project_name VARCHAR(100),
#     PRIMARY KEY (emp_id, project_id)
# );
# ```
#
# In this example, the combination of `emp_id` and `project_id` uniquely identifies each record.
#
# ---

# %%
# %%sql
# CREATE TABLE employee_projects(
#     emp_id INT,
#     project_id INT,
#     project_name VARCHAR(100),
#     PRIMARY KEY (emp_id,project_id)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # 2. FOREIGN KEY
#
# **Definition:**
#
# A **Foreign Key** is a column (or a combination of columns) in one table that refers to the **Primary Key** of another table. It is used to establish a relationship between two tables and maintain **referential integrity**.
#
# A Foreign Key allows duplicate values and can contain `NULL` values (unless restricted by a `NOT NULL` constraint).
#
# ---
#
# ## Characteristics
#
# - Creates a relationship between two tables.
# - References the Primary Key of another table.
# - Maintains referential integrity.
# - Duplicate values are allowed.
# - `NULL` values are allowed (unless specified otherwise).
#
# ---
#
# ## Syntax
#
# ```sql
# CREATE TABLE child_table (
#     column1 datatype,
#     foreign_key_column datatype,
#     FOREIGN KEY (foreign_key_column)
#     REFERENCES parent_table(primary_key_column)
# );
# ```
#
# ---
#
# ## Example
#
# ### Parent Table
#
# ```sql
# CREATE TABLE departments (
#     department_id INT PRIMARY KEY,
#     department_name VARCHAR(100)
# );
# ```
#
# ### Child Table
#
# ```sql
# CREATE TABLE employees (
#     emp_id INT PRIMARY KEY,
#     emp_name VARCHAR(100),
#     department_id INT,
#     FOREIGN KEY (department_id)
#     REFERENCES departments(department_id)
# );
# ```
#
# In this example:
#
# - `department_id` in the **departments** table is the **Primary Key**.
# - `department_id` in the **employees** table is the **Foreign Key**.
# - Every `department_id` in the `employees` table must exist in the `departments` table.
#
# ---
#
# ## Adding a Foreign Key Using ALTER
#
# ### Syntax
#
# ```sql
# ALTER TABLE table_name
# ADD CONSTRAINT constraint_name
# FOREIGN KEY (column_name)
# REFERENCES parent_table(primary_key_column);
# ```
#
# ### Example
#
# ```sql
# ALTER TABLE employees
# ADD CONSTRAINT fk_department
# FOREIGN KEY (department_id)
# REFERENCES departments(department_id);
#
# ```

# %% [markdown]
# # Real-Life Example of a FOREIGN KEY
#
# Consider a **Cab Booking Application** such as Uber or Ola.
#
# - A **Driver** can complete multiple rides.
# - Each **Ride** belongs to one Driver.
# - This relationship is established using a **Foreign Key**.
#
# ---
#
# ## Parent Table - Drivers
#
# ```sql
# CREATE TABLE drivers (
#     driver_id INT PRIMARY KEY,
#     driver_name VARCHAR(100) NOT NULL,
#     license_number VARCHAR(30) UNIQUE
# );
# ```
#
# ---
#
# ## Child Table - Rides
#
# ```sql
# CREATE TABLE rides (
#     ride_id INT PRIMARY KEY,
#     pickup_location VARCHAR(100),
#     dropoff_location VARCHAR(100),
#     ride_date DATE,
#     fare DECIMAL(10,2),
#     driver_id INT,
#
#     FOREIGN KEY (driver_id)
#     REFERENCES drivers(driver_id)
#     ON DELETE CASCADE
# );
# ```
#
# ---
#
# ## Relationship
#
# ```
# Drivers (Parent)
# ------------------------
# driver_id (PK)
# driver_name
# license_number
#       │
#       │ One Driver
#       │
#       ▼
# Rides (Child)
# ------------------------
# ride_id (PK)
# pickup_location
# dropoff_location
# ride_date
# fare
# driver_id (FK)
# ```
#
# One **Driver** can have **multiple Rides**, but each **Ride** belongs to only one Driver.
#
# ---
#
# # What Does `ON DELETE CASCADE` Do?
#
# Suppose the following data exists.
#
# ### Drivers
#
# | driver_id | driver_name |
# |-----------|-------------|
# | 101 | Rahul |
#
# ### Rides
#
# | ride_id | driver_id |
# |---------|-----------|
# | 1 | 101 |
# | 2 | 101 |
# | 3 | 101 |
#
# If we execute:
#
# ```sql
# DELETE FROM drivers
# WHERE driver_id = 101;
# ```
#
# Because the Foreign Key uses **`ON DELETE CASCADE`**, MySQL automatically deletes:
#
# - Driver `101`
# - Ride `1`
# - Ride `2`
# - Ride `3`
#
# This prevents orphan records from remaining in the `rides` table.
#
# ---
#
# # What Happens Without `ON DELETE CASCADE`?
#
# If the Foreign Key is created **without** `ON DELETE CASCADE`:
#
# ```sql
# FOREIGN KEY (driver_id)
# REFERENCES drivers(driver_id);
# ```
#
# Then executing:
#
# ```sql
# DELETE FROM drivers
# WHERE driver_id = 101;
# ```
#
# will result in an error similar to:
#
# ```
# Cannot delete or update a parent row:
# a foreign key constraint fails.
# ```
#
# This happens because ride records still reference that driver.
#
# ---
#
# # Is Physically Deleting Ride Data Always a Good Idea?
#
# Not always.
#
# Imagine a ride-booking company.
#
# A driver leaves the company, but the completed ride history is still important for:
#
# - Revenue reports
# - Customer complaints
# - Tax records
# - Audits
# - Business analytics
#
# If the driver and all rides are deleted using **CASCADE**, the company loses valuable historical data.
#
# ---
#
# # Soft Delete
#
# Instead of deleting records permanently, many companies use a **Soft Delete**.
#
# A new column is added to indicate whether the record is active or deleted.
#
# ---
#
# ## Add the Soft Delete Column
#
# ```sql
# ALTER TABLE drivers
# ADD COLUMN is_deleted BOOLEAN DEFAULT FALSE;
# ```
#
# ---
#
# ## Soft Delete a Driver
#
# Instead of deleting the row:
#
# ```sql
# DELETE FROM drivers
# WHERE driver_id = 101;
# ```
#
# we update the flag:
#
# ```sql
# UPDATE drivers
# SET is_deleted = TRUE
# WHERE driver_id = 101;
# ```
#
# The record still exists in the table, but it is marked as deleted.
#
# ---
#
# ## Fetch Only Active Drivers
#
# ```sql
# SELECT *
# FROM drivers
# WHERE is_deleted = FALSE;
# ```
#
# ---
#
# # Advantages of Soft Delete
#
# - Data is not permanently lost.
# - Historical ride records remain available.
# - Reports and analytics remain accurate.
# - Deleted records can be restored if needed.
# - Supports auditing and regulatory compliance.
#
# ---
#
# # Summary
#
# | ON DELETE CASCADE | Soft Delete |
# |-------------------|-------------|
# | Permanently deletes parent and child records. | Marks records as deleted without removing them. |
# | No historical data is retained. | Historical data is preserved. |
# | Suitable for temporary or non-critical data. | Preferred for business-critical applications. |
# | Automatic deletion of related records. | Requires filtering using the `is_deleted` flag. |
#
# > **Industry Practice:** Most enterprise applications (banking, healthcare, e-commerce, ride-booking, ERP, etc.) prefer **Soft Delete** over permanent deletion to preserve historical data and maintain audit trails.

# %%
# %%sql
# desc tp_employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [('emp_id', 'int', 'NO', 'PRI', None, ''),
#  ('emp_name', 'varchar(100)', 'YES', '', None, ''),
#  ('salary', 'decimal(10,2)', 'YES', '', None, ''),
#  ('gender', 'varchar(100)', 'YES', '', None, ''),
#  ('area', 'varchar(100)', 'YES', '', None, ''),
#  ('age', 'int', 'YES', '', None, ''),
#  ('department_id', 'int', 'YES', '', None, '')]

# %%
# %%sql
# CREATE TABLE tp_departments(
#     department_id INT PRIMARY KEY,
#     department_name varchar(100)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE tp_employees
# ADD CONSTRAINT fk_department
# FOREIGN KEY (department_id)
# REFERENCES tp_departments(department_id);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# desc tp_employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [('emp_id', 'int', 'NO', 'PRI', None, ''),
#  ('emp_name', 'varchar(100)', 'YES', '', None, ''),
#  ('salary', 'decimal(10,2)', 'YES', '', None, ''),
#  ('gender', 'varchar(100)', 'YES', '', None, ''),
#  ('area', 'varchar(100)', 'YES', '', None, ''),
#  ('age', 'int', 'YES', '', None, ''),
#  ('department_id', 'int', 'YES', 'MUL', None, '')]

# %%
# %%sql
# drop table tp_departments;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.DatabaseError) 3730 (HY000): Cannot drop table 'tp_departments' referenced by a foreign key constraint 'fk_department' on table 'tp_employees'.
# [SQL: drop table tp_departments;]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %% [markdown]
# # 3. UNIQUE
#
# **Definition:**
#
# The **UNIQUE** constraint ensures that all values in a column are **unique**. It prevents duplicate values from being inserted into the column. Unlike a **Primary Key**, a `UNIQUE` column can contain `NULL` values (the behavior may vary slightly depending on the database system).
#
# ---
#
# ## Characteristics
#
# - Prevents duplicate values.
# - Helps maintain data uniqueness.
# - Allows `NULL` values (database-dependent).
# - A table can have multiple `UNIQUE` constraints.
#
# ---
#
# ## Syntax
#
# ```sql
# CREATE TABLE table_name (
#     column_name datatype UNIQUE,
#     column2 datatype,
#     column3 datatype
# );
# ```
#
# ---
#
# ## Example
#
# ```sql
# CREATE TABLE employees (
#     emp_id INT PRIMARY KEY,
#     emp_name VARCHAR(100),
#     email VARCHAR(100) UNIQUE,
#     department VARCHAR(50)
# );
# ```
#
# In this example, every employee must have a **unique email address**, and duplicate email values are not allowed.
#
# ---
#
# ## Composite UNIQUE Constraint
#
# A **Composite UNIQUE** constraint ensures that the combination of two or more columns contains unique values.
#
# ### Syntax
#
# ```sql
# CREATE TABLE table_name (
#     column1 datatype,
#     column2 datatype,
#     column3 datatype,
#     UNIQUE (column1, column2)
# );
# ```
#
# ### Example
#
# ```sql
# CREATE TABLE employee_projects (
#     emp_id INT,
#     project_id INT,
#     role VARCHAR(50),
#     UNIQUE (emp_id, project_id)
# );
# ```
#
# In this example, the combination of `emp_id` and `project_id` must be unique.
#
# ---
#
# ## Adding a UNIQUE Constraint Using ALTER
#
# ### Syntax
#
# ```sql
# ALTER TABLE table_name
# ADD CONSTRAINT constraint_name
# UNIQUE (column_name);
# ```
#
# ### Example
#
# ```sql
# ALTER TABLE employees
# ADD CONSTRAINT uq_email
# UNIQUE (email);
# ```

# %%
# %%sql
# alter table tp_employees
# add constraint email
# unique(email);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# desc tp_employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 8 rows affected.
# [('emp_id', 'int', 'NO', 'PRI', None, ''),
#  ('emp_name', 'varchar(100)', 'YES', '', None, ''),
#  ('salary', 'decimal(10,2)', 'YES', '', None, ''),
#  ('gender', 'varchar(100)', 'YES', '', None, ''),
#  ('area', 'varchar(100)', 'YES', '', None, ''),
#  ('age', 'int', 'YES', '', None, ''),
#  ('department_id', 'int', 'YES', 'MUL', None, ''),
#  ('email', 'varchar(100)', 'YES', 'UNI', None, '')]

# %% [markdown]
# # 4. NOT NULL
#
# **Definition:**
#
# The **NOT NULL** constraint ensures that a column **cannot contain `NULL` values**. Every row must have a valid value for that column.
#
# ---
#
# ## Characteristics
#
# - Prevents `NULL` values.
# - Ensures that every record contains a value for the specified column.
# - Can be applied to one or more columns.
# - Commonly used for mandatory fields such as names, email addresses, and IDs.
#
# ---
#
# ## Syntax
#
# ```sql
# CREATE TABLE table_name (
#     column_name datatype NOT NULL,
#     column2 datatype,
#     column3 datatype
# );
# ```
#
# ---
#
# ## Example
#
# ```sql
# CREATE TABLE employees (
#     emp_id INT PRIMARY KEY,
#     emp_name VARCHAR(100) NOT NULL,
#     email VARCHAR(100) NOT NULL,
#     salary DECIMAL(10,2)
# );
# ```
#
# In this example:
#
# - `emp_name` cannot be `NULL`.
# - `email` cannot be `NULL`.
# - Every employee record must contain values for these columns.
#
# ---
#
# ## Adding a NOT NULL Constraint Using ALTER
#
# ### Syntax
#
# ```sql
# ALTER TABLE table_name
# MODIFY COLUMN column_name datatype NOT NULL;
# ```
#
# ### Example
#
# ```sql
# ALTER TABLE employees
# MODIFY COLUMN email VARCHAR(100) NOT NULL;
# ```

# %%
# %%sql
# ALTER TABLE tp_employees
# MODIFY COLUMN emp_number varchar(12) NOT NULL;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# # 5. CHECK
#
# **Definition:**
#
# The **CHECK** constraint is used to restrict the values that can be inserted or updated in a column. It ensures that the data satisfies a specified condition.
#
# ---
#
# ## Characteristics
#
# - Restricts values based on a condition.
# - Helps maintain data accuracy and validity.
# - The condition is checked whenever data is inserted or updated.
# - Can be applied to one or more columns.
#
# ---
#
# ## Syntax
#
# ```sql
# CREATE TABLE table_name (
#     column_name datatype CHECK (condition),
#     column2 datatype,
#     column3 datatype
# );
# ```
#
# ---
#
# ## Example
#
# ```sql
# CREATE TABLE employees (
#     emp_id INT PRIMARY KEY,
#     emp_name VARCHAR(100),
#     age INT CHECK (age >= 18),
#     salary DECIMAL(10,2) CHECK (salary > 0)
# );
# ```
#
# In this example:
#
# - `age` must be **18 or greater**.
# - `salary` must be **greater than 0**.
#
# ---
#
# ## Table-Level CHECK Constraint
#
# A CHECK constraint can also be defined at the table level.
#
# ### Syntax
#
# ```sql
# CREATE TABLE table_name (
#     column1 datatype,
#     column2 datatype,
#     CONSTRAINT constraint_name
#     CHECK (condition)
# );
# ```
#
# ### Example
#
# ```sql
# CREATE TABLE employees (
#     emp_id INT PRIMARY KEY,
#     emp_name VARCHAR(100),
#     age INT,
#     salary DECIMAL(10,2),
#     CONSTRAINT chk_employee
#     CHECK (age >= 18 AND salary > 0)
# );
# ```
#
# ---
#
# ## Adding a CHECK Constraint Using ALTER
#
# ### Syntax
#
# ```sql
# ALTER TABLE table_name
# ADD CONSTRAINT constraint_name
# CHECK (condition);
# ```
#
# ### Example
#
# ```sql
# ALTER TABLE employees
# ADD CONSTRAINT chk_salary
# CHECK (salary > 0);
# ```

# %% [markdown]
# # Minimal Key (Conceptual)
#
# ## Definition
#
# A **Minimal Key** is the **smallest set of attributes (columns)** that can uniquely identify every row in a table.
#
# A key is considered **minimal** if:
#
# - It uniquely identifies every row in the table.
# - No column can be removed from the key while still maintaining uniqueness.
#
# If removing even one column causes the key to lose its uniqueness, then it is a **Minimal Key**.
#
# ---
#
# ## Characteristics
#
# - Uniquely identifies every row.
# - Contains the minimum number of columns required for uniqueness.
# - Removing any column results in the loss of uniqueness.
# - Every Primary Key is a Minimal Key, but not every Minimal Key is chosen as the Primary Key.
#
# ---
#
# # Example of a Minimal Key
#
# Consider the following table:
#
# | student_id | course_id | course_name |
# |------------|-----------|-------------|
# | 101 | C001 | SQL |
# | 101 | C002 | Python |
# | 102 | C001 | SQL |
#
# Suppose the Primary Key is defined as:
#
# ```sql
# PRIMARY KEY (student_id, course_id)
# ```
#
# This is a **Minimal Key** because:
#
# - `student_id` alone **cannot** uniquely identify a row.
# - `course_id` alone **cannot** uniquely identify a row.
# - The combination `(student_id, course_id)` uniquely identifies every record.
# - Removing either column would result in duplicate records.
#
# Therefore, `(student_id, course_id)` is a **Minimal Key**.
#
# ---
#
# # Example of a Non-Minimal Key
#
# Consider the following key:
#
# ```text
# (student_id, course_id, course_name)
# ```
#
# Although this combination can uniquely identify a row, it is **not a Minimal Key**.
#
# Why?
#
# Because:
#
# - `(student_id, course_id)` already uniquely identifies every row.
# - `course_name` is unnecessary.
# - Removing `course_name` still maintains uniqueness.
#
# Therefore,
#
# ```text
# (student_id, course_id, course_name)
# ```
#
# is a **Non-Minimal Key** because it contains an extra column.
#
# ---
#
# # Comparison
#
# | Minimal Key | Non-Minimal Key |
# |--------------|-----------------|
# | Smallest set of columns required for uniqueness. | Contains one or more unnecessary columns. |
# | No column can be removed. | One or more columns can be removed without affecting uniqueness. |
# | Efficient and optimized. | Redundant and less efficient. |
#
# ---
#
# ## Summary
#
# - **Minimal Key** = Smallest possible unique identifier.
# - Every column in the key is necessary.
# - Removing any column breaks uniqueness.
# - Example of a Minimal Key:
#   ```text
#   (student_id, course_id)
#   ```
# - Example of a Non-Minimal Key:
#   ```text
#   (student_id, course_id, course_name)
#   ```
