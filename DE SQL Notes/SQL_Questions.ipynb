# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:123456@localhost
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# # SQL Practice Database
#
# Instead of creating random tables for each SQL topic, we will use a **real-world relational database** throughout this course.
#
# This approach helps us understand how SQL is used in real projects such as ETL, Data Engineering, Data Warehousing, and Backend Development.
#
# ---
#
# # Database Name
#
# ```sql
# CREATE DATABASE sql_master;
# ```
#
# ---
#
# # Real-World Tables
#
# ## 1. customers
#
# Stores customer information.
#
# ```text
# customer_id
# customer_name
# email
# phone
# city
# signup_date
# ```
#
# ---
#
# ## 2. restaurants
#
# Stores restaurant details.
#
# ```text
# restaurant_id
# restaurant_name
# city
# rating
# ```
#
# ---
#
# ## 3. delivery_partners
#
# Stores delivery partner information.
#
# ```text
# partner_id
# partner_name
# vehicle_type
# city
# rating
# ```
#
# ---
#
# ## 4. orders
#
# Stores every customer order.
#
# ```text
# order_id
# customer_id
# restaurant_id
# partner_id
# order_date
# order_status
# payment_method
# total_amount
# delivery_time
# ```
#
# ---
#
# ## 5. order_items
#
# Stores products inside each order.
#
# ```text
# item_id
# order_id
# item_name
# quantity
# price
# ```
#
# ---
#
# ## 6. payments
#
# Stores payment details.
#
# ```text
# payment_id
# order_id
# payment_type
# payment_status
# amount
# payment_date
# ```
#
# ---
#
# # Relationships
#
# ```text
# Customers
#     │
#     │ 1
#     │
#     ▼
# Orders
#     │
#     ├──────────────► Restaurants
#     │
#     ├──────────────► Delivery Partners
#     │
#     ▼
# Order Items
#
# Orders
#    │
#    ▼
# Payments
# ```
#
# ---
#
# # Topics Covered Using These Tables
#
#  CRUD
#  Constraints
#  Aggregate Functions
#  GROUP BY
#  HAVING
#  String Functions
#  NULL Handling
#  CASE WHEN
#  LIMIT
#  ORDER BY
#  Subqueries
#  Joins
#  Self Join
#  CTE
#  Window Functions
#  Ranking Functions
#  Views
#  Stored Procedures
#  Triggers
#  Transactions
#  Indexing
#  ETL Testing Scenarios
#
# ---
#
# # Difficulty Levels
#
# We will solve questions in four levels.
#
# ### Level 1 - Basic
#
# Simple `SELECT`, `WHERE`, `ORDER BY`, `LIMIT`
#
# ---
#
# ### Level 2 - Intermediate
#
# `GROUP BY`, `HAVING`, Aggregate Functions, String Functions
#
# ---
#
# ### Level 3 - Advanced
#
# Subqueries, CTE, Joins, CASE WHEN
#
# ---
#
# ### Level 4 - Interview Level
#
# Window Functions, Ranking, Complex SQL Problems, ETL Testing Scenarios
#
# ---
#
# # Goal
#
# By solving questions on the same database, you will learn:
#
# - How SQL is used in real companies.
# - How ETL Testers validate data.
# - How Data Engineers write SQL.
# - How SQL interview questions are derived from real business problems.

# %% [markdown]
# ---

# %% [markdown]
# ## Lets create those tables and we start coding
#
# ## Create Database
#
# ```sql
# CREATE DATABASE swiggy_db;
#
# USE swiggy_db;
# ```
#
# ---
#
# # 1. Customers Table
#
# ```sql
# CREATE TABLE customers (
#     customer_id INT PRIMARY KEY AUTO_INCREMENT,
#     customer_name VARCHAR(100) NOT NULL,
#     email VARCHAR(100) UNIQUE,
#     phone VARCHAR(15) UNIQUE,
#     city VARCHAR(50),
#     signup_date DATE
# );
# ```
#
# ---
#
# # 2. Restaurants Table
#
# ```sql
# CREATE TABLE restaurants (
#     restaurant_id INT PRIMARY KEY AUTO_INCREMENT,
#     restaurant_name VARCHAR(100) NOT NULL,
#     city VARCHAR(50),
#     rating DECIMAL(2,1)
# );
# ```
#
# ---
#
# # 3. Delivery Partners Table
#
# ```sql
# CREATE TABLE delivery_partners (
#     partner_id INT PRIMARY KEY AUTO_INCREMENT,
#     partner_name VARCHAR(100) NOT NULL,
#     vehicle_type VARCHAR(30),
#     city VARCHAR(50),
#     rating DECIMAL(2,1)
# );
# ```
#
# ---
#
# # 4. Orders Table
#
# ```sql
# CREATE TABLE orders (
#     order_id INT PRIMARY KEY AUTO_INCREMENT,
#
#     customer_id INT NOT NULL,
#     restaurant_id INT NOT NULL,
#     partner_id INT NOT NULL,
#
#     order_date DATE,
#     order_status VARCHAR(30),
#     payment_method VARCHAR(30),
#     total_amount DECIMAL(10,2),
#     delivery_time INT,
#
#     FOREIGN KEY (customer_id)
#     REFERENCES customers(customer_id)
#     ON DELETE CASCADE,
#
#     FOREIGN KEY (restaurant_id)
#     REFERENCES restaurants(restaurant_id)
#     ON DELETE CASCADE,
#
#     FOREIGN KEY (partner_id)
#     REFERENCES delivery_partners(partner_id)
#     ON DELETE CASCADE
# );
# ```
#
# ---
#
# # 5. Order Items Table
#
# ```sql
# CREATE TABLE order_items (
#     item_id INT PRIMARY KEY AUTO_INCREMENT,
#
#     order_id INT NOT NULL,
#
#     item_name VARCHAR(100),
#     quantity INT,
#     price DECIMAL(10,2),
#
#     FOREIGN KEY (order_id)
#     REFERENCES orders(order_id)
#     ON DELETE CASCADE
# );
# ```
#
# ---
#
# # 6. Payments Table
#
# ```sql
# CREATE TABLE payments (
#     payment_id INT PRIMARY KEY AUTO_INCREMENT,
#
#     order_id INT NOT NULL,
#
#     payment_type VARCHAR(30),
#     payment_status VARCHAR(30),
#     amount DECIMAL(10,2),
#     payment_date DATE,
#
#     FOREIGN KEY (order_id)
#     REFERENCES orders(order_id)
#     ON DELETE CASCADE
# );
# ```
#
# ---
#
# # Database Relationship
#
# ```text
#                  Customers
#                      │
#                      │
#                      ▼
#                   Orders
#               /      |      \
#              /       |       \
#             ▼        ▼        ▼
#    Restaurants   Delivery Partners
#             │
#             ▼
#       Order Items
#             │
#             ▼
#          Payments
# ```
#
# ---
#
# # Table Summary
#
# | Table | Purpose |
# |--------|---------|
# | `customers` | Stores customer information. |
# | `restaurants` | Stores restaurant details. |
# | `delivery_partners` | Stores delivery partner information. |
# | `orders` | Stores every order placed by customers. |
# | `order_items` | Stores individual food items in each order. |
# | `payments` | Stores payment information for each order. |

# %%
# %%sql
# -- Creating Database
# CREATE DATABASE swiggy_db;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# -- Use the database
#
# USE swiggy_db;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE customers (
#     customer_id INT PRIMARY KEY AUTO_INCREMENT,
#     customer_name VARCHAR(100) NOT NULL,
#     email VARCHAR(100) UNIQUE,
#     phone VARCHAR(15) UNIQUE,
#     city VARCHAR(50),
#     signup_date DATE
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE restaurants (
#     restaurant_id INT PRIMARY KEY AUTO_INCREMENT,
#     restaurant_name VARCHAR(100) NOT NULL,
#     city VARCHAR(50),
#     rating DECIMAL(2,1)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE delivery_partners (
#     partner_id INT PRIMARY KEY AUTO_INCREMENT,
#     partner_name VARCHAR(100) NOT NULL,
#     vehicle_type VARCHAR(30),
#     city VARCHAR(50),
#     rating DECIMAL(2,1)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE orders (
#     order_id INT PRIMARY KEY AUTO_INCREMENT,
#
#     customer_id INT NOT NULL,
#     restaurant_id INT NOT NULL,
#     partner_id INT NOT NULL,
#
#     order_date DATE,
#     order_status VARCHAR(30),
#     payment_method VARCHAR(30),
#     total_amount DECIMAL(10,2),
#     delivery_time INT,
#
#     FOREIGN KEY (customer_id)
#     REFERENCES customers(customer_id)
#     ON DELETE CASCADE,
#
#     FOREIGN KEY (restaurant_id)
#     REFERENCES restaurants(restaurant_id)
#     ON DELETE CASCADE,
#
#     FOREIGN KEY (partner_id)
#     REFERENCES delivery_partners(partner_id)
#     ON DELETE CASCADE
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE order_items (
#     item_id INT PRIMARY KEY AUTO_INCREMENT,
#
#     order_id INT NOT NULL,
#
#     item_name VARCHAR(100),
#     quantity INT,
#     price DECIMAL(10,2),
#
#     FOREIGN KEY (order_id)
#     REFERENCES orders(order_id)
#     ON DELETE CASCADE
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE payments (
#     payment_id INT PRIMARY KEY AUTO_INCREMENT,
#
#     order_id INT NOT NULL,
#
#     payment_type VARCHAR(30),
#     payment_status VARCHAR(30),
#     amount DECIMAL(10,2),
#     payment_date DATE,
#
#     FOREIGN KEY (order_id)
#     REFERENCES orders(order_id)
#     ON DELETE CASCADE
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# SET FOREIGN_KEY_CHECKS = 0;
#
# TRUNCATE TABLE order_items;
# TRUNCATE TABLE orders;
# TRUNCATE TABLE delivery_partners;
# TRUNCATE TABLE restaurants;
# TRUNCATE TABLE customers;
#
# SET FOREIGN_KEY_CHECKS = 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # SQL Practice Questions
#
# # Question 1 (Easy)
#
# ## Scenario
#
# The management team wants to quickly view the **latest 10 orders** placed by customers.
#
# Write a SQL query to display **all details** of the **10 most recent orders**.
#
# ---
#
# ## Requirements
#
# - Display all columns.
# - Show only the latest **10 orders**.
# - Sort the records by **order_date** in descending order.
#
# ---
#
# ## Expected Concepts
#
# - `SELECT`
# - `ORDER BY`
# - `LIMIT`
#
# ---
#
# ## Expected Output
#
# | order_id | customer_id | restaurant_id | partner_id | order_date | order_status | payment_method | total_amount | delivery_time |
# |----------|-------------|---------------|------------|------------|--------------|----------------|--------------|---------------|
# | ... | ... | ... | ... | ... | ... | ... | ... | ... |
#
# ---
#
# ## Hint
#
# 1. Sort the orders by `order_date` in **descending order**.
# 2. Return only the **first 10 records**.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %% [markdown]
# # we have inserted some dummy records in the tables

# %%
# %%sql
# -- Question 1
# select * from orders
# order by order_date desc
# limit 10;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 10 rows affected.
# [(268, 13, 11, 20, datetime.date(2026, 6, 25), 'Delivered', 'Cash', Decimal('1382.00'), 34),
#  (439, 49, 8, 7, datetime.date(2026, 6, 24), 'Out for Delivery', 'Debit Card', Decimal('1677.00'), 52),
#  (105, 33, 14, 27, datetime.date(2026, 6, 23), 'Out for Delivery', 'Credit Card', Decimal('282.00'), 61),
#  (146, 65, 8, 10, datetime.date(2026, 6, 22), 'Pending', 'Net Banking', Decimal('334.00'), 56),
#  (24, 34, 10, 10, datetime.date(2026, 6, 19), 'Pending', 'UPI', Decimal('2406.00'), 67),
#  (34, 26, 12, 7, datetime.date(2026, 6, 19), 'Delivered', 'Cash', Decimal('1090.00'), 17),
#  (275, 24, 20, 28, datetime.date(2026, 6, 18), 'Cancelled', 'Debit Card', Decimal('2052.00'), 39),
#  (35, 7, 18, 10, datetime.date(2026, 6, 16), 'Pending', 'Wallet', Decimal('642.00'), 35),
#  (453, 24, 9, 23, datetime.date(2026, 6, 16), 'Cancelled', 'Cash', Decimal('2263.00'), 53),
# ...

# %% [markdown]
# # Question 2 (Easy)
#
# ## Scenario
#
# The operations team wants to identify the **top 5 highest-value orders** placed on the platform.
#
# Write a SQL query to display the **top 5 orders** with the highest `total_amount`.
#
# ---
#
# ## Requirements
#
# - Display the following columns:
#   - `order_id`
#   - `customer_id`
#   - `total_amount`
# - Sort the orders by **total_amount** in descending order.
# - Display only the **top 5 records**.
#
# ---
#
# ## Expected Concepts
#
# - `SELECT`
# - `ORDER BY`
# - `LIMIT`
#
# ---
#
# ## Expected Output
#
# | order_id | customer_id | total_amount |
# |----------|-------------|--------------|
# | ... | ... | ... |
# | ... | ... | ... |
# | ... | ... | ... |
# | ... | ... | ... |
# | ... | ... | ... |
#
# ---
#
# ## Hint
#
# 1. Sort the records based on `total_amount`.
# 2. Use **descending order (`DESC`)**.
# 3. Return only the first **5** rows.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
# -- Question 2
# select * from orders
# order by total_amount desc
# limit 5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [(197, 13, 13, 30, datetime.date(2025, 2, 3), 'Out for Delivery', 'Net Banking', Decimal('2499.00'), 44),
#  (160, 56, 4, 25, datetime.date(2026, 1, 12), 'Out for Delivery', 'Debit Card', Decimal('2495.00'), 44),
#  (260, 59, 1, 16, datetime.date(2025, 5, 9), 'Out for Delivery', 'Cash', Decimal('2490.00'), 62),
#  (497, 92, 19, 25, datetime.date(2026, 5, 19), 'Cancelled', 'UPI', Decimal('2488.00'), 63),
#  (112, 46, 10, 20, datetime.date(2026, 5, 29), 'Pending', 'Net Banking', Decimal('2487.00'), 60)]

# %% [markdown]
# # Question 3 (Easy)
#
# ## Scenario
#
# The customer support team wants to identify **all cancelled orders** so they can contact the affected customers and process refunds if necessary.
#
# Write a SQL query to display all orders whose status is **Cancelled**.
#
# ---
#
# ## Requirements
#
# Display the following columns:
#
# - `order_id`
# - `customer_id`
# - `order_date`
# - `order_status`
# - `total_amount`
#
# Only display orders where the status is **Cancelled**.
#
# ---
#
# ## Expected Concepts
#
# - `SELECT`
# - `WHERE`
#
# ---
#
# ## Expected Output
#
# | order_id | customer_id | order_date | order_status | total_amount |
# |----------|-------------|------------|--------------|--------------|
# | ... | ... | ... | Cancelled | ... |
# | ... | ... | ... | Cancelled | ... |
#
# ---
#
# ## Hint
#
# - Use the `WHERE` clause.
# - Filter based on the `order_status` column.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
# select order_id,customer_id,order_date,order_status,total_amount
# from orders
# where order_status = 'Cancelled'
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 96 rows affected.
# [(1, 98, datetime.date(2025, 10, 21), 'Cancelled', Decimal('309.00')),
#  (2, 79, datetime.date(2026, 4, 17), 'Cancelled', Decimal('410.00')),
#  (5, 13, datetime.date(2025, 8, 19), 'Cancelled', Decimal('2019.00')),
#  (8, 88, datetime.date(2025, 3, 25), 'Cancelled', Decimal('1291.00')),
#  (9, 7, datetime.date(2026, 3, 31), 'Cancelled', Decimal('819.00')),
#  (13, 76, datetime.date(2026, 1, 20), 'Cancelled', Decimal('1133.00')),
#  (15, 72, datetime.date(2026, 6, 8), 'Cancelled', Decimal('336.00')),
#  (20, 68, datetime.date(2026, 3, 22), 'Cancelled', Decimal('850.00')),
#  (21, 30, datetime.date(2025, 7, 27), 'Cancelled', Decimal('664.00')),
#  (27, 50, datetime.date(2026, 3, 26), 'Cancelled', Decimal('1703.00')),
#  (42, 85, datetime.date(2025, 5, 20), 'Cancelled', Decimal('1263.00')),
#  (46, 96, datetime.date(2025, 5, 24), 'Cancelled', Decimal('2170.00')),
# ...

# %% [markdown]
# # Question 4 (Easy)
#
# ## Scenario
#
# The finance team wants to review **high-value delivered orders** for auditing purposes.
#
# Write a SQL query to display all **Delivered** orders whose **total_amount is greater than ₹2000**.
#
# ---
#
# ## Requirements
#
# Display:
#
# - order_id
# - customer_id
# - order_status
# - total_amount
#
# Conditions:
#
# - Order status should be **Delivered**
# - Total amount should be **greater than 2000**
#
# ---
#
# ## Expected Concepts
#
# - WHERE
# - AND
# - Comparison Operators (`>`)
#
# ---
#
# ## Hint
#
# You need to satisfy **both conditions**.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
# -- Qestion 4
# select order_id,customer_id,order_status,total_amount
# from orders
# where order_status = "Delivered" and total_amount > 2000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 17 rows affected.
# [(4, 26, 'Delivered', Decimal('2301.00')),
#  (67, 77, 'Delivered', Decimal('2131.00')),
#  (69, 24, 'Delivered', Decimal('2360.00')),
#  (74, 68, 'Delivered', Decimal('2372.00')),
#  (118, 53, 'Delivered', Decimal('2231.00')),
#  (135, 100, 'Delivered', Decimal('2385.00')),
#  (137, 50, 'Delivered', Decimal('2304.00')),
#  (152, 22, 'Delivered', Decimal('2025.00')),
#  (173, 28, 'Delivered', Decimal('2408.00')),
#  (223, 64, 'Delivered', Decimal('2130.00')),
#  (239, 65, 'Delivered', Decimal('2162.00')),
#  (255, 36, 'Delivered', Decimal('2447.00')),
#  (273, 27, 'Delivered', Decimal('2262.00')),
#  (366, 72, 'Delivered', Decimal('2132.00')),
#  (411, 86, 'Delivered', Decimal('2216.00')),
#  (420, 85, 'Delivered', Decimal('2188.00')),
#  (434, 71, 'Delivered', Decimal('2242.00'))]

# %% [markdown]
# # Question 5 (Easy)
#
# ## Scenario
#
# The customer support team needs to review **all pending or preparing orders** so they can monitor orders that have not yet been delivered.
#
# Write a SQL query to display the following columns:
#
# - order_id
# - customer_id
# - order_status
# - total_amount
#
# Display only the orders whose status is either:
#
# - `Pending`
# - `Preparing`
#
# ---
#
# ## Expected Concepts
#
# - WHERE
# - OR
#
# ---
#
# ## Hint
#
# You need to retrieve rows that satisfy **either one** of the two conditions.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
# -- Question 5
# select order_id,customer_id,order_status,total_amount
# from orders
# WHERE order_status IN ('Pending', 'Preparing');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 204 rows affected.
# [(3, 40, 'Preparing', Decimal('339.00')),
#  (6, 69, 'Preparing', Decimal('801.00')),
#  (10, 34, 'Preparing', Decimal('1910.00')),
#  (12, 51, 'Preparing', Decimal('1219.00')),
#  (14, 95, 'Pending', Decimal('1773.00')),
#  (17, 43, 'Preparing', Decimal('795.00')),
#  (18, 89, 'Preparing', Decimal('1091.00')),
#  (19, 99, 'Pending', Decimal('1602.00')),
#  (22, 52, 'Preparing', Decimal('1579.00')),
#  (24, 34, 'Pending', Decimal('2406.00')),
#  (25, 66, 'Pending', Decimal('252.00')),
#  (26, 23, 'Preparing', Decimal('731.00')),
#  (28, 63, 'Preparing', Decimal('1559.00')),
#  (29, 13, 'Preparing', Decimal('520.00')),
#  (30, 47, 'Pending', Decimal('488.00')),
#  (33, 47, 'Preparing', Decimal('2179.00')),
#  (35, 7, 'Pending', Decimal('642.00')),
#  (36, 69, 'Pending', Decimal('1978.00')),
#  (38, 46, 'Pending', Decimal('2162.00')),
#  (39, 77, 'Preparing', Decimal('1073.00')),
# ...

# %% [markdown]
# # Question 6 (Easy)
#
# ## Scenario
#
# The finance team wants to review all orders whose value is between **₹1000 and ₹2000** (inclusive).
#
# Write a SQL query to display:
#
# - order_id
# - customer_id
# - total_amount
#
# Display only the orders where the total amount is between **1000 and 2000**.
#
# ---
#
# ## Expected Concepts
#
# - WHERE
# - BETWEEN
#
# ---
#
# ## Hint
#
# Use the `BETWEEN` operator.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
#
# select order_id,customer_id,total_amount
# from orders
# where total_amount between 1000 AND 2000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 195 rows affected.
# [(8, 88, Decimal('1291.00')),
#  (10, 34, Decimal('1910.00')),
#  (11, 72, Decimal('1376.00')),
#  (12, 51, Decimal('1219.00')),
#  (13, 76, Decimal('1133.00')),
#  (14, 95, Decimal('1773.00')),
#  (18, 89, Decimal('1091.00')),
#  (19, 99, Decimal('1602.00')),
#  (22, 52, Decimal('1579.00')),
#  (27, 50, Decimal('1703.00')),
#  (28, 63, Decimal('1559.00')),
#  (31, 47, Decimal('1592.00')),
#  (34, 26, Decimal('1090.00')),
#  (36, 69, Decimal('1978.00')),
#  (39, 77, Decimal('1073.00')),
#  (42, 85, Decimal('1263.00')),
#  (45, 83, Decimal('1686.00')),
#  (49, 61, Decimal('1417.00')),
#  (51, 3, Decimal('1635.00')),
#  (55, 77, Decimal('1065.00')),
#  (58, 2, Decimal('1560.00')),
#  (59, 97, Decimal('1152.00')),
#  (60, 21, Decimal('1700.00')),
#  (62, 8, Decimal('1642.00')),
#  (63, 83, Decimal('1711.00')),
#  (64, 70, Decimal('1130.00')),
#  (65, 45, Decimal('1878.00')),
#  (68, 28, Decimal('1422.00')),
# ...

# %% [markdown]
# # Question 7 (Easy)
#
# ## Scenario
#
# The operations team wants to identify all orders that were paid using either **UPI** or **Credit Card**.
#
# Write a SQL query to display:
#
# - order_id
# - customer_id
# - payment_method
# - total_amount
#
# Display only the orders where the payment method is:
#
# - `UPI`
# - `Credit Card`
#
# ---
#
# ## Expected Concepts
#
# - WHERE
# - IN
#
# ---
#
# ## Hint
#
# Instead of using multiple `OR` conditions, use the `IN` operator.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
#
# select order_id,customer_id,payment_method,total_amount
# from orders
# where payment_method IN ('UPI','Credit Card');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 159 rows affected.
# [(1, 98, 'Credit Card', Decimal('309.00')),
#  (10, 34, 'Credit Card', Decimal('1910.00')),
#  (13, 76, 'Credit Card', Decimal('1133.00')),
#  (19, 99, 'UPI', Decimal('1602.00')),
#  (21, 30, 'UPI', Decimal('664.00')),
#  (24, 34, 'UPI', Decimal('2406.00')),
#  (25, 66, 'Credit Card', Decimal('252.00')),
#  (29, 13, 'UPI', Decimal('520.00')),
#  (36, 69, 'UPI', Decimal('1978.00')),
#  (38, 46, 'UPI', Decimal('2162.00')),
#  (40, 47, 'UPI', Decimal('213.00')),
#  (41, 87, 'UPI', Decimal('465.00')),
#  (42, 85, 'UPI', Decimal('1263.00')),
#  (45, 83, 'UPI', Decimal('1686.00')),
#  (47, 71, 'Credit Card', Decimal('2394.00')),
#  (50, 12, 'UPI', Decimal('863.00')),
#  (51, 3, 'Credit Card', Decimal('1635.00')),
#  (52, 62, 'Credit Card', Decimal('617.00')),
#  (53, 57, 'UPI', Decimal('842.00')),
#  (58, 2, 'UPI', Decimal('1560.00')),
#  (61, 79, 'UPI', Decimal('223.00')),
#  (62, 8, 'UPI', Decimal('1642.00')),
# ...

# %% [markdown]
# # Question 8 (Easy)
#
# ## Scenario
#
# The marketing team wants to identify customers whose names **start with the letter 'R'** so they can send a personalized promotional campaign.
#
# Write a SQL query to display:
#
# - customer_id
# - customer_name
# - city
#
# Display only the customers whose names **start with 'R'**.
#
# ---
#
# ## Expected Concepts
#
# - WHERE
# - LIKE
# - `%`
#
# ---
#
# ## Hint
#
# Use the `LIKE` operator with the appropriate wildcard.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
#
# select customer_id, customer_name, city
# from customers
# where customer_name like 'R%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 10 rows affected.
# [(4, 'Rahul4', 'Delhi'),
#  (7, 'Rahul7', 'Mumbai'),
#  (21, 'Rahul21', 'Delhi'),
#  (25, 'Ramesh25', 'Delhi'),
#  (53, 'Ramesh53', 'Pune'),
#  (56, 'Rahul56', 'Delhi'),
#  (67, 'Rahul67', 'Delhi'),
#  (71, 'Ramesh71', 'Mumbai'),
#  (87, 'Ramesh87', 'Hyderabad'),
#  (93, 'Ramesh93', 'Hyderabad')]

# %% [markdown]
# # Question 9 (Easy)
#
# ## Scenario
#
# The customer support team wants to identify customers whose names **end with the number '7'**.
#
# Write a SQL query to display:
#
# - customer_id
# - customer_name
# - city
#
# Display only the customers whose names **end with '7'**.
#
# ---
#
# ## Expected Concepts
#
# - WHERE
# - LIKE
# - `%`
#
# ---
#
# ## Hint
#
# Think about where the `%` wildcard should be placed.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
#
# select customer_id,customer_name,city
# from customers
# where customer_name like '%7';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 10 rows affected.
# [(7, 'Rahul7', 'Mumbai'),
#  (17, 'Priya17', 'Mumbai'),
#  (27, 'Karthik27', 'Delhi'),
#  (37, 'Priya37', 'Chennai'),
#  (47, 'Pooja47', 'Delhi'),
#  (57, 'Priya57', 'Pune'),
#  (67, 'Rahul67', 'Delhi'),
#  (77, 'Arun77', 'Chennai'),
#  (87, 'Ramesh87', 'Hyderabad'),
#  (97, 'Lavanya97', 'Pune')]

# %% [markdown]
# # Question 10 (Easy)
#
# ## Scenario
#
# The marketing team wants to identify customers whose names start with **'R'** and contain **exactly 7 characters**.
#
# Write a SQL query to display:
#
# - customer_id
# - customer_name
# - city
#
# Display only the customers whose names:
#
# - Start with **R**
# - Have **exactly 7 characters**
#
# ---
#
# ## Expected Concepts
#
# - `WHERE`
# - `LIKE`
# - `_` (Single Character Wildcard)
#
# ---
#
# ## Hint
#
# Remember:
#
# - `_` represents **exactly one character**.
# - `%` represents **zero or more characters**.
#
# ---
#
# ## Example
#
# The following names should match:
#
# ```text
# Ramesh7
# Rahul21
# ```
#
# The following names should **not** match:
#
# ```text
# Rahul4
# Raj7
# Raghavan12
# ```
#
# ---
#
# **Difficulty Level:** ⭐⭐ Easy

# %%
# %%sql
#
# select customer_id, customer_name,city
# from customers
# where customer_name like '%R_______';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [(25, 'Ramesh25', 'Delhi'),
#  (53, 'Ramesh53', 'Pune'),
#  (71, 'Ramesh71', 'Mumbai'),
#  (87, 'Ramesh87', 'Hyderabad'),
#  (93, 'Ramesh93', 'Hyderabad')]

# %% [markdown]
# # Question 11 (Easy)
#
# ## Scenario
#
# The customer support team wants to identify all customers whose names contain the word **"Rahul"**.
#
# Write a SQL query to display:
#
# - customer_id
# - customer_name
# - city
#
# Display only the customers whose names contain **Rahul** anywhere in the name.
#
# ---
#
# ## Expected Concepts
#
# - WHERE
# - LIKE
# - `%`
#
# ---
#
# ## Hint
#
# The word **Rahul** can appear:
#
# - At the beginning
# - In the middle
# - At the end
#
# Use the `%` wildcard appropriately.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
# select customer_id,customer_name,city
# from customers
# where customer_name like '%Rahul%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [(4, 'Rahul4', 'Delhi'),
#  (7, 'Rahul7', 'Mumbai'),
#  (21, 'Rahul21', 'Delhi'),
#  (56, 'Rahul56', 'Delhi'),
#  (67, 'Rahul67', 'Delhi')]

# %% [markdown]
# # Question 12 (Easy)
#
# ## Scenario
#
# The management team wants to know the **total number of orders** placed on the platform.
#
# Write a SQL query to find the total number of orders.
#
# ---
#
# ## Requirements
#
# Display:
#
# - Total Orders
#
# The output should contain only **one row** with the total count of orders.
#
# ---
#
# ## Expected Concepts
#
# - `COUNT()`
#
# ---
#
# ## Expected Output
#
# | total_orders |
# |--------------|
# | 500 |
#
# *(Your result may vary depending on the data.)*
#
# ---
#
# ## Hint
#
# Use the `COUNT()` aggregate function.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
#
# select count(*)
# from orders;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [(500,)]

# %% [markdown]
# # Question 13 (Easy)
#
# ## Scenario
#
# The finance team wants to know the **total revenue generated** from all orders placed on the platform.
#
# Write a SQL query to calculate the **total revenue**.
#
# ---
#
# ## Requirements
#
# Display:
#
# - Total Revenue
#
# The output should contain only **one row** with the total revenue.
#
# ---
#
# ## Expected Concepts
#
# - `SUM()`
#
# ---
#
# ## Expected Output
#
# | total_revenue |
# |---------------|
# | 658920.00 |
#
# *(Your result may vary depending on the data.)*
#
# ---
#
# ## Hint
#
# Use the `SUM()` aggregate function on the `total_amount` column.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
#
# select sum(total_amount) as total_revenue
# from orders;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [(Decimal('658711.00'),)]

# %% [markdown]
# # Question 14 (Easy)
#
# ## Scenario
#
# The business analytics team wants to know the **average order value** of all orders placed on the platform.
#
# Write a SQL query to calculate the **average order amount**.
#
# ---
#
# ## Requirements
#
# Display:
#
# - Average Order Value
#
# The output should contain only **one row** with the average order value.
#
# ---
#
# ## Expected Concepts
#
# - `AVG()`
#
# ---
#
# ## Expected Output
#
# | average_order_value |
# |---------------------|
# | 1324.58 |
#
# *(Your result may vary depending on the data.)*
#
# ---
#
# ## Hint
#
# Use the `AVG()` aggregate function on the `total_amount` column.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
#
# select Avg(total_amount)
# from orders;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [(Decimal('1317.422000'),)]

# %% [markdown]
# # Question 15 (Easy)
#
# ## Scenario
#
# The operations team wants to know:
#
# - Which order has the **highest order amount**?
# - Which order has the **lowest order amount**?
#
# Write a SQL query to find the **maximum** and **minimum** order amounts.
#
# ---
#
# ## Requirements
#
# Display:
#
# - Highest Order Amount
# - Lowest Order Amount
#
# The output should contain only **one row**.
#
# ---
#
# ## Expected Concepts
#
# - `MAX()`
# - `MIN()`
#
# ---
#
# ## Expected Output
#
# | highest_order | lowest_order |
# |---------------|--------------|
# | 2499.00 | 150.00 |
#
# *(Your result may vary depending on the data.)*
#
# ---
#
# ## Hint
#
# Use both aggregate functions in the same query.
#
# ---
#
# **Difficulty Level:** ⭐ Easy

# %%
# %%sql
# select MIN(total_amount) total_amount, MAX(total_amount)  lowest_order
# from orders;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [(Decimal('170.00'), Decimal('2499.00'))]

# %% [markdown]
# # Question 16 (Easy)
#
# ## Scenario
#
# The management team wants to know **how many orders are in each order status**.
#
# Write a SQL query to display the **total number of orders** for each status.
#
# ---
#
# ## Requirements
#
# Display:
#
# - `order_status`
# - `total_orders`
#
# Group the records based on the order status.
#
# ---
#
# ## Expected Concepts
#
# - `COUNT()`
# - `GROUP BY`
#
# ---
#
# ## Expected Output
#
# | order_status | total_orders |
# |--------------|-------------:|
# | Delivered | 145 |
# | Preparing | 102 |
# | Pending | 95 |
# | Out for Delivery | 88 |
# | Cancelled | 70 |
#
# *(Your output may vary depending on the data.)*
#
# ---
#
# ## Hint
#
# 1. Count the number of orders.
# 2. Group the records by `order_status`.
#
# ---
#
# **Difficulty Level:** ⭐⭐ Easy

# %%
# %%sql
#
# select order_status, count(*)
# from orders
# group by order_status;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [('Cancelled', 96),
#  ('Preparing', 97),
#  ('Delivered', 96),
#  ('Pending', 107),
#  ('Out for Delivery', 104)]

# %% [markdown]
# # Question 17 (Easy)
#
# ## Scenario
#
# The finance team wants to know the **total revenue generated for each payment method**.
#
# Write a SQL query to display the **total revenue** collected through each payment method.
#
# ---
#
# ## Requirements
#
# Display:
#
# - `payment_method`
# - `total_revenue`
#
# Group the records by `payment_method`.
#
# ---
#
# ## Expected Concepts
#
# - `SUM()`
# - `GROUP BY`
#
# ---
#
# ## Expected Output
#
# | payment_method | total_revenue |
# |----------------|--------------:|
# | UPI | 125430.00 |
# | Credit Card | 108920.00 |
# | Debit Card | 97350.00 |
# | Cash | 86450.00 |
# | Wallet | 75620.00 |
# | Net Banking | 68400.00 |
#
# *(Your output may vary depending on the data.)*
#
# ---
#
# ## Hint
#
# 1. Calculate the total amount using `SUM()`.
# 2. Group the records by `payment_method`.
#
# ---
#
# **Difficulty Level:** ⭐⭐ Easy

# %%
# %%sql
#
# select payment_method, sum(total_amount)
# from orders
# group by payment_method;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 6 rows affected.
# [('Credit Card', Decimal('105342.00')),
#  ('Wallet', Decimal('101314.00')),
#  ('Debit Card', Decimal('116892.00')),
#  ('Net Banking', Decimal('130498.00')),
#  ('Cash', Decimal('99990.00')),
#  ('UPI', Decimal('104675.00'))]

# %% [markdown]
# # Question 18 (Easy)
#
# ## Scenario
#
# The operations team wants to know the **average delivery time** for each order status.
#
# Write a SQL query to display the **average delivery time** based on the order status.
#
# ---
#
# ## Requirements
#
# Display:
#
# - `order_status`
# - `average_delivery_time`
#
# Group the records by `order_status`.
#
# ---
#
# ## Expected Concepts
#
# - `AVG()`
# - `GROUP BY`
#
# ---
#
# ## Expected Output
#
# | order_status | average_delivery_time |
# |--------------|----------------------:|
# | Delivered | 38.45 |
# | Preparing | 47.21 |
# | Pending | 52.87 |
# | Out for Delivery | 41.32 |
# | Cancelled | 29.76 |
#
# *(Your output may vary depending on the data.)*
#
# ---
#
# ## Hint
#
# 1. Use the `AVG()` function.
# 2. Group the records by `order_status`.
# 3. Give the average column a meaningful alias.
#
# ---
#
# ## Bonus Challenge
#
# Sort the output by **average delivery time** in **descending order**.
#
# ---
#
# ## Expected Concepts
#
# - `AVG()`
# - `GROUP BY`
# - `ORDER BY`
#
# ---
#
# **Difficulty Level:** ⭐⭐ Easy

# %%
# %%sql
#
# select order_status, avg(delivery_time) avg_delivery_time
# from orders
# group by order_status
# order by avg(delivery_time) desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [('Cancelled', Decimal('45.1667')),
#  ('Delivered', Decimal('44.5104')),
#  ('Pending', Decimal('43.9626')),
#  ('Out for Delivery', Decimal('43.4327')),
#  ('Preparing', Decimal('42.3608'))]

# %% [markdown]
# # Question 19 (Medium)
#
# ## Scenario
#
# The finance department wants to identify **payment methods that have generated more than ₹100,000 in revenue**.
#
# Write a SQL query to display:
#
# - payment_method
# - total_revenue
#
# Only display payment methods whose total revenue is **greater than ₹100,000**.
#
# ---
#
# ## Requirements
#
# - Group the records by `payment_method`.
# - Calculate the total revenue using `SUM()`.
# - Filter the grouped results using the appropriate clause.
# - Sort the revenue in descending order.
#
# ---
#
# ## Expected Concepts
#
# - `SUM()`
# - `GROUP BY`
# - `HAVING`
# - `ORDER BY`
#
# ---
# ## Sample Output
#
# | payment_method | total_revenue |
# |----------------|--------------:|
# | UPI | 128,450.00 |
# | Credit Card | 116,720.00 |
# | Debit Card | 109,840.00 |
#
# > **Note:** The above values are only sample outputs. Your actual results may vary based on the data in your database.
#
# ---
# ## Hint
#
# You **cannot** use `WHERE` to filter aggregate values.
#
# Think carefully about **which clause executes after `GROUP BY`**.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐ Medium

# %%
# %%sql
#
# select payment_method, sum(total_amount) as total_revenue
# from orders
# group by payment_method
# having sum(total_amount) > 100000
# order by total_revenue desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [('Net Banking', Decimal('130498.00')),
#  ('Debit Card', Decimal('116892.00')),
#  ('Credit Card', Decimal('105342.00')),
#  ('UPI', Decimal('104675.00')),
#  ('Wallet', Decimal('101314.00'))]

# %% [markdown]
# # Question 20 (Interview Level ⭐⭐⭐)
#
# ## Scenario
#
# The finance team wants to analyze **high-value delivered orders**.
#
# They only want to consider:
#
# - Orders with the status **Delivered**
#
# After grouping, they want to know **which payment methods have generated more than ₹30,000** from these delivered orders.
#
# Write a SQL query to display:
#
# - `payment_method`
# - `total_revenue`
#
# ---
#
# ## Requirements
#
# - Consider only **Delivered** orders.
# - Group the records by `payment_method`.
# - Calculate the total revenue.
# - Display only payment methods whose revenue is **greater than ₹30,000**.
# - Sort the result by **total_revenue** in descending order.
#
# ---
#
# ## Expected Concepts
#
# - `WHERE`
# - `GROUP BY`
# - `SUM()`
# - `HAVING`
# - `ORDER BY`
#
# ---
#
# ## Sample Output
#
# | payment_method | total_revenue |
# |----------------|--------------:|
# | UPI | 48,520.00 |
# | Credit Card | 44,810.00 |
# | Wallet | 38,930.00 |
# | Debit Card | 33,760.00 |
#
# > **Note:** The above values are sample outputs. Your actual results may vary depending on your dataset.
#
# ---
#
# ## Hint
#
# Think about the SQL execution order:
#
# 1. Filter individual rows.
# 2. Group the remaining rows.
# 3. Calculate the aggregate.
# 4. Filter the groups.
# 5. Sort the result.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐ Interview Level

# %%
# %%sql
#
# select payment_method, sum(total_amount) as total_revenue
# from orders
# where order_status = 'Delivered'
# group by payment_method
# having sum(total_amount) > 30000
# order by total_revenue desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [('Debit Card', Decimal('30637.00'))]

# %% [markdown]
# # Question 21 (Subquery - Single Row ⭐⭐)
#
# ## Scenario
#
# The HR team wants to identify **customers who have placed orders whose value is greater than the average order amount**.
#
# Write a SQL query to display:
#
# - `order_id`
# - `customer_id`
# - `total_amount`
#
# Display only the orders whose **total_amount** is greater than the **average order amount**.
#
# ---
#
# ## Requirements
#
# - Calculate the average order amount using a subquery.
# - Compare each order's amount with the average.
# - Display only the orders above the average.
#
# ---
#
# ## Expected Concepts
#
# - Single Row Subquery
# - `AVG()`
# - `WHERE`
#
# ---
#
# ## Sample Output
#
# | order_id | customer_id | total_amount |
# |----------|------------:|-------------:|
# | 8 | 21 | 1850.00 |
# | 12 | 45 | 2230.00 |
# | 27 | 13 | 1980.00 |
# | ... | ... | ... |
#
# > **Note:** The output above is only a sample. Your actual results may differ.
#
# ---
#
# ## Hint
#
# The subquery should return only **one value**.
#
# Think about this process:
#
# ```text
# Step 1
# --------
# Find the Average Order Amount
#
# ↓
#
# Step 2
# --------
# Compare every order with that average
#
# ↓
#
# Step 3
# --------
# Return only those greater than the average
# ```
#
# ---
#
# **Difficulty Level:** ⭐⭐ Easy

# %%
# %%sql
#
# select order_id,customer_id,total_amount
# from orders
# where total_amount >  (
#     select avg(total_amount)
#     from orders
# )
# limit 10;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 10 rows affected.
# [(4, 26, Decimal('2301.00')),
#  (5, 13, Decimal('2019.00')),
#  (10, 34, Decimal('1910.00')),
#  (11, 72, Decimal('1376.00')),
#  (14, 95, Decimal('1773.00')),
#  (19, 99, Decimal('1602.00')),
#  (22, 52, Decimal('1579.00')),
#  (23, 42, Decimal('2464.00')),
#  (24, 34, Decimal('2406.00')),
#  (27, 50, Decimal('1703.00'))]

# %% [markdown]
# # Question 22 (Subquery - Single Row ⭐⭐)
#
# ## Scenario
#
# The management team wants to identify **all orders placed in the restaurant with the highest rating**.
#
# Write a SQL query to display:
#
# - `order_id`
# - `customer_id`
# - `restaurant_id`
# - `total_amount`
#
# Display only the orders placed in the **highest-rated restaurant**.
#
# ---
#
# ## Requirements
#
# - Do **not** use `JOIN`.
# - Use a **single-row subquery**.
# - The query should work dynamically even if the highest rating changes.
#
# ---
#
# ## Expected Concepts
#
# - Single Row Subquery
# - `MAX()`
# - `WHERE`
#
# ---
#
# ## Sample Output
#
# | order_id | customer_id | restaurant_id | total_amount |
# |----------|------------:|--------------:|-------------:|
# | 12 | 45 | 7 | 1850.00 |
# | 28 | 19 | 7 | 920.00 |
# | 56 | 81 | 7 | 2310.00 |
# | ... | ... | ... | ... |
#
# > **Note:** The output above is only a sample. Your actual results may differ.
#
# ---
#
# ## Hint
#
# Think about the execution order.
#
# ```text
# Step 1
# --------
# Find the Highest Rating
#
# ↓
#
# Step 2
# --------
# Find the Restaurant ID having that Rating
#
# ↓
#
# Step 3
# --------
# Find all Orders belonging to that Restaurant
# ```
#
# ---
#
# ## Challenge
#
# Solve it using **only one SQL query**.
#
# ---
#
# **Difficulty Level:** ⭐⭐ Easy

# %%
# %%sql
# desc restaurants;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [('restaurant_id', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('restaurant_name', 'varchar(100)', 'NO', '', None, ''),
#  ('city', 'varchar(50)', 'YES', '', None, ''),
#  ('rating', 'decimal(2,1)', 'YES', '', None, '')]

# %%
# %%sql
# select
# order_id,
# customer_id,
# restaurant_id,
# total_amount
# from orders
# where restaurant_id = (
#     select restaurant_id
#     from restaurants
#     order by rating desc
#     limit 1
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 33 rows affected.
# [(12, 51, 1, Decimal('1219.00')),
#  (25, 66, 1, Decimal('252.00')),
#  (38, 46, 1, Decimal('2162.00')),
#  (55, 77, 1, Decimal('1065.00')),
#  (64, 70, 1, Decimal('1130.00')),
#  (67, 77, 1, Decimal('2131.00')),
#  (68, 28, 1, Decimal('1422.00')),
#  (78, 85, 1, Decimal('1724.00')),
#  (79, 5, 1, Decimal('321.00')),
#  (140, 7, 1, Decimal('2008.00')),
#  (144, 87, 1, Decimal('571.00')),
#  (147, 64, 1, Decimal('750.00')),
#  (153, 83, 1, Decimal('375.00')),
#  (162, 2, 1, Decimal('1883.00')),
#  (166, 1, 1, Decimal('795.00')),
#  (202, 29, 1, Decimal('1471.00')),
#  (215, 31, 1, Decimal('1668.00')),
#  (228, 54, 1, Decimal('953.00')),
#  (231, 54, 1, Decimal('2436.00')),
#  (232, 35, 1, Decimal('1552.00')),
#  (260, 59, 1, Decimal('2490.00')),
#  (288, 75, 1, Decimal('2486.00')),
#  (338, 52, 1, Decimal('1377.00')),
#  (354, 21, 1, Decimal('388.00')),
#  (400, 20, 1, Decimal('1787.00')),
# ...

# %%
# %%sql
# -- another solution for 21 Questions
# SELECT
#     order_id,
#     customer_id,
#     restaurant_id,
#     total_amount
# FROM orders
# WHERE restaurant_id = (
#     SELECT restaurant_id
#     FROM restaurants
#     WHERE rating = (
#         SELECT MAX(rating)
#         FROM restaurants
#     )
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 33 rows affected.
# [(12, 51, 1, Decimal('1219.00')),
#  (25, 66, 1, Decimal('252.00')),
#  (38, 46, 1, Decimal('2162.00')),
#  (55, 77, 1, Decimal('1065.00')),
#  (64, 70, 1, Decimal('1130.00')),
#  (67, 77, 1, Decimal('2131.00')),
#  (68, 28, 1, Decimal('1422.00')),
#  (78, 85, 1, Decimal('1724.00')),
#  (79, 5, 1, Decimal('321.00')),
#  (140, 7, 1, Decimal('2008.00')),
#  (144, 87, 1, Decimal('571.00')),
#  (147, 64, 1, Decimal('750.00')),
#  (153, 83, 1, Decimal('375.00')),
#  (162, 2, 1, Decimal('1883.00')),
#  (166, 1, 1, Decimal('795.00')),
#  (202, 29, 1, Decimal('1471.00')),
#  (215, 31, 1, Decimal('1668.00')),
#  (228, 54, 1, Decimal('953.00')),
#  (231, 54, 1, Decimal('2436.00')),
#  (232, 35, 1, Decimal('1552.00')),
#  (260, 59, 1, Decimal('2490.00')),
#  (288, 75, 1, Decimal('2486.00')),
#  (338, 52, 1, Decimal('1377.00')),
#  (354, 21, 1, Decimal('388.00')),
#  (400, 20, 1, Decimal('1787.00')),
# ...

# %% [markdown]
# # Question 23 (Subquery - Multiple Row ⭐⭐⭐)
#
# ## Scenario
#
# The operations team wants to identify **all orders placed in restaurants located in Chennai**.
#
# Write a SQL query to display:
#
# - `order_id`
# - `customer_id`
# - `restaurant_id`
# - `total_amount`
#
# Display only the orders that belong to restaurants located in **Chennai**.
#
# ---
#
# ## Requirements
#
# - Do **not** use `JOIN`.
# - Use a **Multiple Row Subquery**.
# - The subquery should return multiple restaurant IDs.
#
# ---
#
# ## Expected Concepts
#
# - Multiple Row Subquery
# - `IN`
# - `WHERE`
#
# ---
#
# ## Sample Output
#
# | order_id | customer_id | restaurant_id | total_amount |
# |----------|------------:|--------------:|-------------:|
# | 2 | 45 | 3 | 1850.00 |
# | 15 | 72 | 8 | 920.00 |
# | 34 | 19 | 12 | 2310.00 |
# | ... | ... | ... | ... |
#
# > **Note:** The output above is only a sample. Your actual results may differ.
#
# ---
#
# ## Hint
#
# Think about the execution order.
#
# ```text
# Step 1
# --------
# Find all Restaurant IDs located in Chennai
#
# ↓
#
# Restaurant IDs:
# 3
# 8
# 12
# 17
#
# ↓
#
# Step 2
# --------
# Use those IDs to find all matching orders
#
# ↓
#
# Return the Result
# ```
#
# ---
#
# ## Challenge
#
# - Do **not** use `=`.
# - Think about **why `IN` is required**.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐ Medium

# %%
# %%sql
# select order_id,
# customer_id,
# restaurant_id,
# total_amount
# from orders
# where restaurant_id IN (
#     select restaurant_id
#     from restaurants
#     where city = 'Chennai'
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 96 rows affected.
# [(8, 88, 12, Decimal('1291.00')),
#  (16, 82, 12, Decimal('418.00')),
#  (34, 26, 12, Decimal('1090.00')),
#  (40, 47, 12, Decimal('213.00')),
#  (72, 42, 12, Decimal('355.00')),
#  (102, 27, 12, Decimal('2370.00')),
#  (127, 17, 12, Decimal('1116.00')),
#  (170, 2, 12, Decimal('386.00')),
#  (224, 72, 12, Decimal('2436.00')),
#  (225, 25, 12, Decimal('940.00')),
#  (236, 34, 12, Decimal('2258.00')),
#  (255, 36, 12, Decimal('2447.00')),
#  (256, 60, 12, Decimal('188.00')),
#  (264, 46, 12, Decimal('1594.00')),
#  (296, 28, 12, Decimal('557.00')),
#  (315, 17, 12, Decimal('977.00')),
#  (319, 40, 12, Decimal('1130.00')),
#  (320, 100, 12, Decimal('1736.00')),
#  (321, 91, 12, Decimal('2217.00')),
#  (364, 94, 12, Decimal('482.00')),
#  (381, 79, 12, Decimal('739.00')),
#  (391, 70, 12, Decimal('1831.00')),
#  (408, 20, 12, Decimal('1439.00')),
#  (435, 57, 12, Decimal('1510.00')),
# ...

# %% [markdown]
# # Question 24 (Subquery - Multiple Row ⭐⭐⭐)
#
# ## Scenario
#
# The business team wants to identify **all orders that were NOT placed in restaurants located in Chennai**.
#
# Write a SQL query to display:
#
# - `order_id`
# - `customer_id`
# - `restaurant_id`
# - `total_amount`
#
# Display only the orders placed in restaurants **outside Chennai**.
#
# ---
#
# ## Requirements
#
# - Do **not** use `JOIN`.
# - Use a **Multiple Row Subquery**.
# - Use the `NOT IN` operator.
#
# ---
#
# ## Expected Concepts
#
# - Multiple Row Subquery
# - `NOT IN`
# - `WHERE`
#
# ---
#
# ## Hint
#
# Think about the execution order.
#
# ```text
# Step 1
# --------
# Find all Restaurant IDs located in Chennai
#
# ↓
#
# 12
# 15
# 18
# 20
#
# ↓
#
# Step 2
# --------
# Return all orders whose restaurant_id is NOT in that list.
# ```
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐ Medium

# %%
# %%sql
#
# select order_id,
# customer_id,
# restaurant_id,
# total_amount
# from orders
# where restaurant_id NOT IN  (
#     select restaurant_id
#     from restaurants
#     where city  = 'Chennai'
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 404 rows affected.
# [(1, 98, 2, Decimal('309.00')),
#  (3, 40, 11, Decimal('339.00')),
#  (4, 26, 14, Decimal('2301.00')),
#  (5, 13, 9, Decimal('2019.00')),
#  (6, 69, 11, Decimal('801.00')),
#  (7, 9, 2, Decimal('268.00')),
#  (9, 7, 3, Decimal('819.00')),
#  (10, 34, 14, Decimal('1910.00')),
#  (11, 72, 11, Decimal('1376.00')),
#  (12, 51, 1, Decimal('1219.00')),
#  (13, 76, 11, Decimal('1133.00')),
#  (14, 95, 7, Decimal('1773.00')),
#  (15, 72, 5, Decimal('336.00')),
#  (17, 43, 8, Decimal('795.00')),
#  (18, 89, 6, Decimal('1091.00')),
#  (19, 99, 8, Decimal('1602.00')),
#  (20, 68, 10, Decimal('850.00')),
#  (21, 30, 20, Decimal('664.00')),
#  (22, 52, 7, Decimal('1579.00')),
#  (23, 42, 6, Decimal('2464.00')),
#  (24, 34, 10, Decimal('2406.00')),
#  (25, 66, 1, Decimal('252.00')),
#  (26, 23, 20, Decimal('731.00')),
#  (27, 50, 6, Decimal('1703.00')),
#  (29, 13, 2, Decimal('520.00')),
#  (30, 47, 8, Decimal('488.00')),
# ...

# %% [markdown]
# # Question 25 (Correlated Subquery ⭐⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy management team wants to identify **customers who have placed an order that is greater than their own average order amount**.
#
# In other words,
#
# For every customer,
#
# - Calculate that customer's average order amount.
# - Display only the orders whose amount is greater than **that customer's own average**.
#
# ---
#
# ## Example
#
# ### Customer 101
#
# | Order | Amount |
# |--------|--------|
# | 1 | 500 |
# | 2 | 900 |
# | 3 | 700 |
#
# Average = 700
#
# Return
#
# ```text
# 900
# ```
#
# ---
#
# ### Customer 102
#
# | Order | Amount |
# |--------|--------|
# | 4 | 1500 |
# | 5 | 1000 |
# | 6 | 500 |
#
# Average = 1000
#
# Return
#
# ```text
# 1500
# ```
#
# Notice:
#
# Each customer has a **different average**.
#
# ---
#
# ## Requirements
#
# Display
#
# - order_id
# - customer_id
# - total_amount
#
# Return only the orders whose amount is greater than that customer's average order amount.
#
# ---
#
# ## Expected Concepts
#
# - Correlated Subquery
# - AVG()
# - WHERE
#
# ---
#
# ## Hint
#
# The subquery must execute **once for every customer**.
#
# Think about how the inner query can identify the **current customer** being processed.
#
# ---
#
# ## Execution Flow
#
# ```text
# Outer Query Reads Customer 13
#
# ↓
#
# Subquery Calculates
#
# Average Order Amount of Customer 13
#
# ↓
#
# Compare
#
# Current Order Amount
#
# >
#
# Customer 13 Average
#
# ↓
#
# Return Result
#
# ↓
#
# Move to Next Customer
#
# ↓
#
# Execute Subquery Again
# ```
#
# ---
#
# ## Challenge
#
# - Do **not** use `GROUP BY`.
# - Do **not** use `JOIN`.
# - Use only a **Correlated Subquery**.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐ Hard

# %%
# %%sql
# select
# order_id,
# customer_id,
# total_amount
# from orders o
# where total_amount > (
#     select avg(total_amount)
#     from orders
#     where customer_id = o.customer_id
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 249 rows affected.
# [(4, 26, Decimal('2301.00')),
#  (5, 13, Decimal('2019.00')),
#  (10, 34, Decimal('1910.00')),
#  (12, 51, Decimal('1219.00')),
#  (13, 76, Decimal('1133.00')),
#  (14, 95, Decimal('1773.00')),
#  (19, 99, Decimal('1602.00')),
#  (22, 52, Decimal('1579.00')),
#  (23, 42, Decimal('2464.00')),
#  (24, 34, Decimal('2406.00')),
#  (27, 50, Decimal('1703.00')),
#  (31, 47, Decimal('1592.00')),
#  (33, 47, Decimal('2179.00')),
#  (36, 69, Decimal('1978.00')),
#  (38, 46, Decimal('2162.00')),
#  (45, 83, Decimal('1686.00')),
#  (46, 96, Decimal('2170.00')),
#  (47, 71, Decimal('2394.00')),
#  (48, 40, Decimal('926.00')),
#  (51, 3, Decimal('1635.00')),
#  (56, 13, Decimal('2094.00')),
#  (58, 2, Decimal('1560.00')),
#  (59, 97, Decimal('1152.00')),
#  (60, 21, Decimal('1700.00')),
#  (62, 8, Decimal('1642.00')),
#  (63, 83, Decimal('1711.00')),
#  (65, 45, Decimal('1878.00')),
#  (66, 88, Decimal('2016.00')),
# ...

# %% [markdown]
# # Question 26 (Correlated Subquery ⭐⭐⭐⭐)
#
# ## Scenario
#
# Swiggy wants to identify **high-value orders**.
#
# For every restaurant, display only the orders whose **total_amount** is **greater than the average order amount of that same restaurant**.
#
# ---
#
# ## Example
#
# ### Restaurant 5
#
# | Order | Amount |
# |--------|-------:|
# | 1 | 450 |
# | 2 | 900 |
# | 3 | 750 |
#
# Average = 700
#
# Return
#
# ```text
# 900
# 750
# ```
#
# ---
#
# ### Restaurant 8
#
# | Order | Amount |
# |--------|-------:|
# | 4 | 1200 |
# | 5 | 800 |
# | 6 | 1000 |
#
# Average = 1000
#
# Return
#
# ```text
# 1200
# ```
#
# Notice that **every restaurant has its own average**.
#
# ---
#
# ## Requirements
#
# Display:
#
# - order_id
# - restaurant_id
# - customer_id
# - total_amount
#
# Return only the orders whose amount is greater than the **average order amount of that restaurant**.
#
# ---
#
# ## Expected Concepts
#
# - Correlated Subquery
# - AVG()
# - WHERE
# - Table Aliases
#
# ---
#
# ## Hint
#
# Think about how you solved the previous question.
#
# Previously you compared using:
#
# ```text
# Customer Average
# ```
#
# Now think:
#
# ```text
# Restaurant Average
# ```
#
# Only **one column changes**.
#
# ---
#
# ## Execution Flow
#
# ```text
# Outer Query Reads Order
#
# ↓
#
# Restaurant = 8
#
# ↓
#
# Inner Query
#
# Calculate Average Order Amount
#
# WHERE restaurant_id = 8
#
# ↓
#
# Compare
#
# Current Order Amount
#
# >
#
# Restaurant Average
#
# ↓
#
# Return Row
#
# ↓
#
# Move to Next Order
# ```
#
# ---
#
# ## Challenge
#
# - Do not use JOIN.
# - Do not use GROUP BY.
# - Use only a Correlated Subquery.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐ Hard

# %%
# %%sql
#
# select order_id,
# restaurant_id,
# customer_id,
# total_amount
# from orders o
# where total_amount > (
#     SELECT AVG(total_amount)
#     FROM orders
#     where restaurant_id = o.restaurant_id
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 244 rows affected.
# [(4, 14, 26, Decimal('2301.00')),
#  (5, 9, 13, Decimal('2019.00')),
#  (10, 14, 34, Decimal('1910.00')),
#  (11, 11, 72, Decimal('1376.00')),
#  (14, 7, 95, Decimal('1773.00')),
#  (19, 8, 99, Decimal('1602.00')),
#  (22, 7, 52, Decimal('1579.00')),
#  (23, 6, 42, Decimal('2464.00')),
#  (24, 10, 34, Decimal('2406.00')),
#  (27, 6, 50, Decimal('1703.00')),
#  (28, 16, 63, Decimal('1559.00')),
#  (31, 19, 47, Decimal('1592.00')),
#  (33, 15, 47, Decimal('2179.00')),
#  (36, 11, 69, Decimal('1978.00')),
#  (38, 1, 46, Decimal('2162.00')),
#  (45, 2, 83, Decimal('1686.00')),
#  (46, 13, 96, Decimal('2170.00')),
#  (47, 17, 71, Decimal('2394.00')),
#  (49, 18, 61, Decimal('1417.00')),
#  (51, 8, 3, Decimal('1635.00')),
#  (56, 9, 13, Decimal('2094.00')),
#  (58, 10, 2, Decimal('1560.00')),
#  (60, 7, 21, Decimal('1700.00')),
#  (62, 19, 8, Decimal('1642.00')),
#  (63, 19, 83, Decimal('1711.00')),
# ...

# %% [markdown]
# # Question 27 (Correlated Subquery ⭐⭐⭐⭐⭐)
#
# ## Scenario
#
# Swiggy wants to identify its **best customers**.
#
# Display all customers who have placed **at least one order worth more than ₹2000**.
#
# ---
#
# ## Requirements
#
# Display:
#
# - customer_id
# - customer_name
# - city
#
# Only display customers who have placed **at least one order greater than ₹2000**.
#
# ---
#
# ## Expected Concepts
#
# - Correlated Subquery
# - EXISTS
#
# ---
#
# ## Hint
#
# Think about this process.
#
# Customer 1
#
# ↓
#
# Does this customer have an order > ₹2000?
#
# ↓
#
# YES
#
# ↓
#
# Return Customer
#
# -------------------------
#
# Customer 2
#
# ↓
#
# Does this customer have an order > ₹2000?
#
# ↓
#
# NO
#
# ↓
#
# Ignore Customer
#
# -------------------------
#
# Customer 3
#
# ↓
#
# YES
#
# ↓
#
# Return Customer
#
# ```
#
# ---
#
# ## Challenge
#
# - Do **not** use `JOIN`.
# - Do **not** use `IN`.
# - Use only `EXISTS`.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐⭐ (Interview Level)

# %%
# %%sql
#
# select
# customer_id,
# customer_name,
# city
# from customers c
# where EXISTS  (
#     select customer_id
#     from orders
#     where total_amount > 2000 and
#     c.customer_id = customer_id
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 62 rows affected.
# [(4, 'Rahul4', 'Delhi'),
#  (5, 'Suresh5', 'Pune'),
#  (6, 'Keerthi6', 'Mumbai'),
#  (7, 'Rahul7', 'Mumbai'),
#  (10, 'Karthik10', 'Chennai'),
#  (13, 'Meena13', 'Bangalore'),
#  (15, 'Deepa15', 'Pune'),
#  (16, 'Anitha16', 'Chennai'),
#  (17, 'Priya17', 'Mumbai'),
#  (18, 'Keerthi18', 'Pune'),
#  (21, 'Rahul21', 'Delhi'),
#  (22, 'Karthik22', 'Chennai'),
#  (23, 'Suresh23', 'Bangalore'),
#  (24, 'Deepa24', 'Delhi'),
#  (26, 'Nisha26', 'Hyderabad'),
#  (27, 'Karthik27', 'Delhi'),
#  (28, 'Suresh28', 'Delhi'),
#  (29, 'Suresh29', 'Hyderabad'),
#  (30, 'Pooja30', 'Bangalore'),
#  (31, 'Gokul31', 'Mumbai'),
#  (32, 'Lavanya32', 'Delhi'),
#  (34, 'Meena34', 'Delhi'),
#  (35, 'Nisha35', 'Bangalore'),
#  (36, 'Suresh36', 'Pune'),
#  (39, 'Vijay39', 'Mumbai'),
#  (42, 'Lavanya42', 'Delhi'),
#  (43, 'Meena43', 'Pune'),
#  (46, 'Karthik46', 'Hyderabad'),
#  (47, 'Pooja47', 'Delhi'),
#  (50, 'Gokul50', 'Hyderabad'),
# ...

# %% [markdown]
# # Question 28 (Correlated Subquery - NOT EXISTS ⭐⭐⭐⭐⭐)
#
# ## Scenario
#
# Swiggy wants to identify **inactive customers**.
#
# Display all customers who **have never placed an order**.
#
# ---
#
# ## Requirements
#
# Display:
#
# - `customer_id`
# - `customer_name`
# - `city`
#
# Return only the customers who **do not have any orders**.
#
# ---
#
# ## Expected Concepts
#
# - Correlated Subquery
# - `NOT EXISTS`
#
# ---
#
# ## Sample Output
#
# | customer_id | customer_name | city |
# |-------------|---------------|------|
# | 101 | Rahul | Chennai |
# | 115 | Priya | Bangalore |
# | ... | ... | ... |
#
# > **Note:** The output above is only a sample. Your actual results may differ.
#
# ---
#
# ## Hint
#
# Think about the execution flow.
#
# ```text
# Current Customer = 1
#
# ↓
#
# Does an order exist?
#
# ↓
#
# YES
#
# ↓
#
# Ignore Customer
#
# ----------------------
#
# Current Customer = 2
#
# ↓
#
# Does an order exist?
#
# ↓
#
# NO
#
# ↓
#
# Return Customer
#
# ----------------------
#
# Current Customer = 3
#
# ↓
#
# Does an order exist?
#
# ↓
#
# YES
#
# ↓
#
# Ignore Customer
# ```
#
# ---
#
# ## Challenge
#
# - Do **not** use `LEFT JOIN`.
# - Do **not** use `NOT IN`.
# - Use only `NOT EXISTS`.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐⭐ (Interview Level)

# %%
# %%sql
# select
# customer_id,
# customer_name,
# city
# from customers c
# where NOT EXISTS (
#     select 1
#     from orders o
#     where o.customer_id = c.customer_id
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(19, 'Suresh19', 'Bangalore'),
#  (101, 'Rohit Kumar', 'Chennai'),
#  (102, 'Anjali Devi', 'Bangalore')]

# %% [markdown]
# # Question 29 (Subquery - ALL ⭐⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy management team wants to identify the **most expensive order** in the entire platform.
#
# Write a SQL query to display:
#
# - `order_id`
# - `customer_id`
# - `restaurant_id`
# - `total_amount`
#
# Return only the order(s) whose amount is **greater than or equal to every other order amount**.
#
# ---
#
# ## Requirements
#
# - Do **not** use `MAX()`.
# - Do **not** use `ORDER BY`.
# - Use only the `ALL` operator.
#
# ---
#
# ## Expected Concepts
#
# - Multiple Row Subquery
# - `ALL`
#
# ---
#
# ## Sample Output
#
# | order_id | customer_id | restaurant_id | total_amount |
# |----------|------------:|--------------:|-------------:|
# | 487 | 92 | 14 | 2500.00 |
#
# > **Note:** The output above is only a sample.
#
# ---
#
# ## Hint
#
# Think about the meaning of `ALL`.
#
# ```text
# 2500 >= ALL (
#     1200
#     1500
#     1800
#     2200
# )
# ```
#
# Is it true?
#
# ↓
#
# Yes
#
# ↓
#
# Return the row.
#
# ---
#
# ## Challenge
#
# - Don't use `MAX()`.
# - Don't use `ORDER BY`.
# - Solve it using `ALL`.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐ Hard

# %%
# %%sql
#
# select order_id,
# customer_id,
# restaurant_id,
# total_amount
# from orders
# where total_amount >= all (
#     select total_amount
#     from orders
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(197, 13, 13, Decimal('2499.00'))]

# %% [markdown]
# # Question 30 (Subquery - ANY ⭐⭐⭐⭐)
#
# ## Scenario
#
# Swiggy wants to identify all orders whose amount is **greater than at least one order placed by Customer ID = 13**.
#
# Write a SQL query to display:
#
# - order_id
# - customer_id
# - restaurant_id
# - total_amount
#
# Display only those orders whose `total_amount` is **greater than ANY order amount** placed by **Customer 13**.
#
# ---
#
# ## Requirements
#
# - Do **not** use `MIN()`.
# - Do **not** use `ORDER BY`.
# - Use the `ANY` operator.
#
# ---
#
# ## Expected Concepts
#
# - Multiple Row Subquery
# - `ANY`
#
# ---
#
# ## Hint
#
# Suppose Customer 13 has the following order amounts:
#
# ```text
# 500
# 900
# 1500
# ```
#
# Now evaluate:
#
# ```text
# 1000 > ANY (
# 500
# 900
# 1500
# )
# ```
#
# ↓
#
# ```text
# 1000 > 500 ✔
#
# 1000 > 900 ✔
#
# 1000 > 1500 ✘
# ```
#
# Since **at least one comparison is true**, the condition evaluates to **TRUE**.
#
# ---
#
# ## Challenge
#
# - Do not use aggregate functions.
# - Use only `ANY`.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐ Hard

# %%
# %%sql
# select order_id,
# customer_id,
# restaurant_id,
# total_amount
# from orders
# where total_amount > ANY (
#     Select total_amount
#     from orders
#     where customer_id=13
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 422 rows affected.
# [(4, 26, 14, Decimal('2301.00')),
#  (5, 13, 9, Decimal('2019.00')),
#  (6, 69, 11, Decimal('801.00')),
#  (8, 88, 12, Decimal('1291.00')),
#  (9, 7, 3, Decimal('819.00')),
#  (10, 34, 14, Decimal('1910.00')),
#  (11, 72, 11, Decimal('1376.00')),
#  (12, 51, 1, Decimal('1219.00')),
#  (13, 76, 11, Decimal('1133.00')),
#  (14, 95, 7, Decimal('1773.00')),
#  (17, 43, 8, Decimal('795.00')),
#  (18, 89, 6, Decimal('1091.00')),
#  (19, 99, 8, Decimal('1602.00')),
#  (20, 68, 10, Decimal('850.00')),
#  (21, 30, 20, Decimal('664.00')),
#  (22, 52, 7, Decimal('1579.00')),
#  (23, 42, 6, Decimal('2464.00')),
#  (24, 34, 10, Decimal('2406.00')),
#  (26, 23, 20, Decimal('731.00')),
#  (27, 50, 6, Decimal('1703.00')),
#  (28, 63, 16, Decimal('1559.00')),
#  (29, 13, 2, Decimal('520.00')),
#  (31, 47, 19, Decimal('1592.00')),
#  (32, 81, 13, Decimal('672.00')),
#  (33, 47, 15, Decimal('2179.00')),
# ...

# %% [markdown]
# # Question 31 (Nested Subquery ⭐⭐⭐⭐⭐)
#
# ## Scenario
#
# Swiggy wants to identify **all orders placed in the highest-rated restaurant located in Chennai**.
#
# Display:
#
# - order_id
# - customer_id
# - restaurant_id
# - total_amount
#
# ---
#
# ## Requirements
#
# - Do **not** use `JOIN`.
# - Use **nested subqueries**.
# - Do **not** use `ORDER BY`.
#
# ---
#
# ## Expected Concepts
#
# - Nested Subqueries
# - `MAX()`
# - Single Row Subquery
#
# ---
#
# ## Hint
#
# Think about the execution order.
#
# Step 1
#
# Find the highest rating among restaurants in Chennai.
#
# ↓
#
# Step 2
#
# Find the restaurant having that rating.
#
# ↓
#
# Step 3
#
# Find all orders placed in that restaurant.
#
# ---
#
# ## Challenge
#
# Solve it using **three levels of queries**.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐⭐ (Interview Level)

# %%
# %%sql
#
# select order_id,
# customer_id,
# restaurant_id,
# total_amount
# from orders o
# where o.restaurant_id =  (
# 		select restaurant_id
# 		from restaurants
# 		where rating = (
# 			select max(rating)
# 			from restaurants
# 			where city = 'Chennai'
# 		)
# 	);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 24 rows affected.
# [(2, 79, 13, Decimal('410.00')),
#  (32, 81, 13, Decimal('672.00')),
#  (46, 96, 13, Decimal('2170.00')),
#  (83, 93, 13, Decimal('858.00')),
#  (90, 25, 13, Decimal('254.00')),
#  (106, 72, 13, Decimal('2402.00')),
#  (114, 32, 13, Decimal('2197.00')),
#  (129, 69, 13, Decimal('423.00')),
#  (139, 87, 13, Decimal('1802.00')),
#  (156, 48, 13, Decimal('1278.00')),
#  (173, 28, 13, Decimal('2408.00')),
#  (197, 13, 13, Decimal('2499.00')),
#  (212, 32, 13, Decimal('837.00')),
#  (229, 35, 13, Decimal('1693.00')),
#  (239, 65, 13, Decimal('2162.00')),
#  (269, 71, 13, Decimal('1246.00')),
#  (290, 14, 13, Decimal('1371.00')),
#  (328, 34, 13, Decimal('843.00')),
#  (330, 4, 13, Decimal('2418.00')),
#  (331, 62, 13, Decimal('776.00')),
#  (375, 66, 13, Decimal('2139.00')),
#  (390, 1, 13, Decimal('1637.00')),
#  (394, 46, 13, Decimal('471.00')),
#  (487, 46, 13, Decimal('963.00'))]

# %% [markdown]
# # Question 32 (INNER JOIN ⭐⭐)
#
# ## Scenario
#
# The Swiggy operations team wants to generate a report showing **which customer placed which order**.
#
# Write a SQL query to display:
#
# - `order_id`
# - `customer_name`
# - `total_amount`
#
# Display only the customers who have placed orders.
#
# ---
#
# ## Requirements
#
# - Use an **INNER JOIN**.
# - Join the `customers` and `orders` tables.
# - Display only the matching records.
#
# ---
#
# ## Expected Concepts
#
# - INNER JOIN
# - Primary Key
# - Foreign Key
# - Table Aliases
#
# ---
#
# ## Tables Involved
#
# ### customers
#
# | Column |
# |---------|
# | customer_id |
# | customer_name |
#
# ### orders
#
# | Column |
# |---------|
# | order_id |
# | customer_id |
# | total_amount |
#
# ---
#
# ## Expected Output
#
# | order_id | customer_name | total_amount |
# |----------|---------------|-------------:|
# | 101 | Rahul | 850 |
# | 102 | Priya | 1200 |
# | ... | ... | ... |
#
# > **Note:** The output above is only a sample. Your actual results may differ.
#
# ---
#
# ## Hint
#
# Think about the relationship between the two tables.
#
# ```text
# Customers
#
# customer_id (PK)
#
#         │
#         │
#         ▼
#
# Orders
#
# customer_id (FK)
# ```
#
# Now ask yourself:
#
# > Which columns should be used in the `ON` condition?
#
# ---
#
# ## Challenge
#
# - Do **not** use a subquery.
# - Use **table aliases**.
# - Return only matching records.
#
# ---
#
# **Difficulty Level:** ⭐⭐ Easy

# %%
# %%sql
# SELECT
# 	o.order_id,
# 	c.customer_name,
# 	o.total_amount
# FROM orders o
# INNER JOIN customers c
# ON c.customer_id = o.customer_id;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# 500 rows affected.
# [(166, 'Nisha1', Decimal('795.00')),
#  (193, 'Nisha1', Decimal('599.00')),
#  (285, 'Nisha1', Decimal('1080.00')),
#  (390, 'Nisha1', Decimal('1637.00')),
#  (58, 'Deepa2', Decimal('1560.00')),
#  (162, 'Deepa2', Decimal('1883.00')),
#  (170, 'Deepa2', Decimal('386.00')),
#  (307, 'Deepa2', Decimal('639.00')),
#  (360, 'Deepa2', Decimal('1917.00')),
#  (373, 'Deepa2', Decimal('1156.00')),
#  (51, 'Ajay3', Decimal('1635.00')),
#  (283, 'Ajay3', Decimal('655.00')),
#  (352, 'Ajay3', Decimal('528.00')),
#  (478, 'Ajay3', Decimal('1826.00')),
#  (329, 'Rahul4', Decimal('1484.00')),
#  (330, 'Rahul4', Decimal('2418.00')),
#  (344, 'Rahul4', Decimal('1683.00')),
#  (79, 'Suresh5', Decimal('321.00')),
#  (323, 'Suresh5', Decimal('1684.00')),
#  (482, 'Suresh5', Decimal('2418.00')),
#  (123, 'Keerthi6', Decimal('565.00')),
#  (265, 'Keerthi6', Decimal('854.00')),
#  (368, 'Keerthi6', Decimal('2480.00')),
# ...

# %% [markdown]
# # Question 33 (INNER JOIN ⭐⭐)
#
# ## Scenario
#
# The Swiggy analytics team wants to know **from which restaurant each order was placed**.
#
# Write a SQL query to display:
#
# - order_id
# - restaurant_name
# - total_amount
#
# Display only the orders that have a matching restaurant.
#
# ---
#
# ## Requirements
#
# - Use an INNER JOIN.
# - Join the `orders` and `restaurants` tables.
# - Display only matching records.
#
# ---
#
# ## Expected Concepts
#
# - INNER JOIN
# - Primary Key
# - Foreign Key
# - Table Aliases
#
# ---
#
# ## Tables Involved
#
# ### orders
#
# | Column |
# |---------|
# | order_id |
# | restaurant_id |
# | total_amount |
#
# ### restaurants
#
# | Column |
# |---------|
# | restaurant_id |
# | restaurant_name |
#
# ---
#
# ## Expected Output
#
# | order_id | restaurant_name | total_amount |
# |----------|-----------------|-------------:|
# | 101 | A2B | 850 |
# | 102 | KFC | 1200 |
# | ... | ... | ... |
#
# ---
#
# ## Hint
#
# Relationship:
#
# restaurants.restaurant_id (PK)
#
# ↓
#
# orders.restaurant_id (FK)
#
# ---
#
# ## Challenge
#
# - Use aliases.
# - Do not use `SELECT *`.
# - Return only matching rows.
#
# ---
#
# **Difficulty Level:** ⭐⭐ Easy

# %%
# %%sql
# SELECT
# 	o.order_id,
# 	r.restaurant_name,
# 	o.total_amount
# FROM orders o
# INNER JOIN restaurants r
# ON o.restaurant_id = r.restaurant_id;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 500 rows affected.
# [(12, 'A2B', Decimal('1219.00')),
#  (25, 'A2B', Decimal('252.00')),
#  (38, 'A2B', Decimal('2162.00')),
#  (55, 'A2B', Decimal('1065.00')),
#  (64, 'A2B', Decimal('1130.00')),
#  (67, 'A2B', Decimal('2131.00')),
#  (68, 'A2B', Decimal('1422.00')),
#  (78, 'A2B', Decimal('1724.00')),
#  (79, 'A2B', Decimal('321.00')),
#  (140, 'A2B', Decimal('2008.00')),
#  (144, 'A2B', Decimal('571.00')),
#  (147, 'A2B', Decimal('750.00')),
#  (153, 'A2B', Decimal('375.00')),
#  (162, 'A2B', Decimal('1883.00')),
#  (166, 'A2B', Decimal('795.00')),
#  (202, 'A2B', Decimal('1471.00')),
#  (215, 'A2B', Decimal('1668.00')),
#  (228, 'A2B', Decimal('953.00')),
#  (231, 'A2B', Decimal('2436.00')),
#  (232, 'A2B', Decimal('1552.00')),
#  (260, 'A2B', Decimal('2490.00')),
#  (288, 'A2B', Decimal('2486.00')),
#  (338, 'A2B', Decimal('1377.00')),
#  (354, 'A2B', Decimal('388.00')),
#  (400, 'A2B', Decimal('1787.00')),
# ...

# %% [markdown]
# # Question 34 (INNER JOIN ⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy management team wants a report showing:
#
# - Which customer placed an order
# - From which restaurant
# - How much the order cost
#
# Write a SQL query to display:
#
# - order_id
# - customer_name
# - restaurant_name
# - total_amount
#
# ---
#
# ## Requirements
#
# - Use INNER JOIN.
# - Join **three tables**:
#   - customers
#   - orders
#   - restaurants
# - Use table aliases.
#
# ---
#
# ## Expected Concepts
#
# - Multiple INNER JOINs
# - Primary Key & Foreign Key relationships
# - Table Aliases
#
# ---
#
# ## Relationships
#
# customers.customer_id (PK)
#
# ↓
#
# orders.customer_id (FK)
#
# orders.restaurant_id (FK)
#
# ↓
#
# restaurants.restaurant_id (PK)
#
# ---
#
# ## Expected Output
#
# | order_id | customer_name | restaurant_name | total_amount |
# |----------|---------------|-----------------|-------------:|
# | 101 | Rahul | A2B | 850 |
# | 102 | Priya | KFC | 1200 |
# | ... | ... | ... | ... |
#
# ---
#
# ## Challenge
#
# - Use only INNER JOIN.
# - Do not use subqueries.
# - Do not use SELECT *.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐ Medium

# %%
# %%sql
# SELECT
# 	o.order_id,
# 	c.customer_name,
# 	r.restaurant_name,
# 	o.total_amount
# FROM orders o
# INNER JOIN restaurants r
# ON o.restaurant_id = r.restaurant_id
# INNER JOIN customers c
# ON c.customer_id = o.customer_id;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 500 rows affected.
# [(12, 'Vijay51', 'A2B', Decimal('1219.00')),
#  (25, 'Nisha66', 'A2B', Decimal('252.00')),
#  (38, 'Karthik46', 'A2B', Decimal('2162.00')),
#  (55, 'Arun77', 'A2B', Decimal('1065.00')),
#  (64, 'Ajay70', 'A2B', Decimal('1130.00')),
#  (67, 'Arun77', 'A2B', Decimal('2131.00')),
#  (68, 'Suresh28', 'A2B', Decimal('1422.00')),
#  (78, 'Gokul85', 'A2B', Decimal('1724.00')),
#  (79, 'Suresh5', 'A2B', Decimal('321.00')),
#  (140, 'Rahul7', 'A2B', Decimal('2008.00')),
#  (144, 'Ramesh87', 'A2B', Decimal('571.00')),
#  (147, 'Suresh64', 'A2B', Decimal('750.00')),
#  (153, 'Keerthi83', 'A2B', Decimal('375.00')),
#  (162, 'Deepa2', 'A2B', Decimal('1883.00')),
#  (166, 'Nisha1', 'A2B', Decimal('795.00')),
#  (202, 'Suresh29', 'A2B', Decimal('1471.00')),
#  (215, 'Gokul31', 'A2B', Decimal('1668.00')),
#  (228, 'Harish54', 'A2B', Decimal('953.00')),
#  (231, 'Harish54', 'A2B', Decimal('2436.00')),
# ...

# %% [markdown]
# # Question 35 (INNER JOIN ⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy management team wants to find all **Delivered** orders along with the customer and restaurant details.
#
# Display:
#
# - order_id
# - customer_name
# - restaurant_name
# - total_amount
# - order_status
#
# ---
#
# ## Requirements
#
# - Join the following tables:
#   - customers
#   - orders
#   - restaurants
# - Display only **Delivered** orders.
# - Use INNER JOIN.
# - Use table aliases.
#
# ---
#
# ## Expected Concepts
#
# - INNER JOIN
# - WHERE
# - Multiple Table Joins
#
# ---
#
# ## Challenge
#
# - No subqueries.
# - No SELECT *.
# - Use proper aliases.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐ Medium

# %%
# %%sql
#
# SELECT
# 	o.order_id,
# 	c.customer_name,
# 	r.restaurant_name,
# 	o.total_amount,
# 	o.order_status
# FROM orders o
# INNER JOIN restaurants r
# ON o.restaurant_id = r.restaurant_id
# INNER JOIN customers c
# ON c.customer_id = o.customer_id
# where o.order_status ='Delivered';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 96 rows affected.
# [(4, 'Nisha26', 'The Bowl Company', Decimal('2301.00'), 'Delivered'),
#  (7, 'Gokul9', 'Dominos', Decimal('268.00'), 'Delivered'),
#  (11, 'Priya72', 'Anjappar', Decimal('1376.00'), 'Delivered'),
#  (32, 'Pooja81', 'Barbeque Nation', Decimal('672.00'), 'Delivered'),
#  (34, 'Nisha26', 'Copper Kitchen', Decimal('1090.00'), 'Delivered'),
#  (37, 'Nisha35', 'Wow Momo', Decimal('845.00'), 'Delivered'),
#  (44, 'Suresh92', 'Sangeetha', Decimal('194.00'), 'Delivered'),
#  (57, 'Suresh92', 'Hot Chips', Decimal('924.00'), 'Delivered'),
#  (58, 'Deepa2', 'Sangeetha', Decimal('1560.00'), 'Delivered'),
#  (63, 'Keerthi83', 'Hotel Saravana', Decimal('1711.00'), 'Delivered'),
#  (65, 'Priya45', 'SS Hyderabad Biryani', Decimal('1878.00'), 'Delivered'),
#  (67, 'Arun77', 'A2B', Decimal('2131.00'), 'Delivered'),
#  (69, 'Deepa24', 'Pizza Hut', Decimal('2360.00'), 'Delivered'),
# ...

# %% [markdown]
# # Question 36 (INNER JOIN ⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy management team wants to know **how much revenue each restaurant has generated**.
#
# Write a SQL query to display:
#
# - restaurant_name
# - total_revenue
#
# Where:
#
# - `total_revenue` is the sum of `total_amount` for each restaurant.
#
# ---
#
# ## Requirements
#
# - Join:
#   - orders
#   - restaurants
# - Use **INNER JOIN**.
# - Use **SUM()**.
# - Group the result by restaurant.
#
# ---
#
# ## Expected Concepts
#
# - INNER JOIN
# - GROUP BY
# - SUM()
# - Aggregate Functions
#
# ---
#
# ## Expected Output
#
# | restaurant_name | total_revenue |
# |-----------------|--------------:|
# | A2B | 15420 |
# | KFC | 12250 |
# | Domino's | 18340 |
# | ... | ... |
#
# ---
#
# ## Hint
#
# Relationship
#
# ```
# orders.restaurant_id
#
# ↓
#
# restaurants.restaurant_id
# ```
#
# After joining,
#
# think about:
#
# ```
# Restaurant
#
# ↓
#
# Group
#
# ↓
#
# Calculate Total Revenue
# ```
#
# ---
#
# ## Challenge
#
# - Do not use subqueries.
# - Use GROUP BY.
# - Use SUM().
# - Use table aliases.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐ Medium

# %%
# %%sql
# SELECT
# 	r.restaurant_name,
# 	SUM(o.total_amount)
# FROM restaurants r
# INNER JOIN orders o
# ON o.restaurant_id = r.restaurant_id
# group by r.restaurant_name;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 20 rows affected.
# [('A2B', Decimal('43874.00')),
#  ('Dominos', Decimal('29790.00')),
#  ('Pizza Hut', Decimal('27267.00')),
#  ('KFC', Decimal('26101.00')),
#  ('McDonalds', Decimal('41902.00')),
#  ('Subway', Decimal('24823.00')),
#  ('Behrouz Biryani', Decimal('29725.00')),
#  ('Burger King', Decimal('34209.00')),
#  ('SS Hyderabad Biryani', Decimal('37101.00')),
#  ('Sangeetha', Decimal('32256.00')),
#  ('Anjappar', Decimal('47340.00')),
#  ('Copper Kitchen', Decimal('36712.00')),
#  ('Barbeque Nation', Decimal('33929.00')),
#  ('The Bowl Company', Decimal('45766.00')),
#  ('Wow Momo', Decimal('35465.00')),
#  ('EatFit', Decimal('27073.00')),
#  ('Buhari', Decimal('22167.00')),
#  ('Hot Chips', Decimal('25168.00')),
#  ('Hotel Saravana', Decimal('32102.00')),
#  ('Salem RR', Decimal('25941.00'))]

# %% [markdown]
# # Question 37 (INNER JOIN ⭐⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy finance team wants to identify restaurants that have generated **more than ₹30,000 in revenue**.
#
# Write a SQL query to display:
#
# - restaurant_name
# - total_revenue
#
# Display only restaurants whose total revenue is **greater than ₹30,000**.
#
# ---
#
# ## Requirements
#
# - Join:
#   - restaurants
#   - orders
# - Use INNER JOIN.
# - Use SUM().
# - Use GROUP BY.
# - Filter the grouped result using HAVING.
#
# ---
#
# ## Expected Concepts
#
# - INNER JOIN
# - GROUP BY
# - SUM()
# - HAVING
#
# ---
#
# ## Expected Output
#
# | restaurant_name | total_revenue |
# |-----------------|--------------:|
# | A2B | 43874 |
# | Burger King | 34209 |
# | SS Hyderabad Biryani | 37101 |
# | ... | ... |
#
# ---
#
# ## Hint
#
# Execution order:
#
# Restaurants
#
# ↓
#
# INNER JOIN Orders
#
# ↓
#
# GROUP BY restaurant_name
#
# ↓
#
# SUM(total_amount)
#
# ↓
#
# HAVING SUM(total_amount) > 30000
#
# ↓
#
# Return Result
#
# ---
#
# ## Challenge
#
# - Do not use WHERE.
# - Use HAVING correctly.
# - Alias the SUM column as `total_revenue`.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐

# %%
# %%sql
# SELECT
# 	r.restaurant_name,
# 	sum(total_amount) as total_revenue
# from orders o
# INNER JOIN restaurants r
# ON o.restaurant_id = r.restaurant_id
# group by r.restaurant_name
# having sum(total_amount) > 30000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 11 rows affected.
# [('A2B', Decimal('43874.00')),
#  ('McDonalds', Decimal('41902.00')),
#  ('Burger King', Decimal('34209.00')),
#  ('SS Hyderabad Biryani', Decimal('37101.00')),
#  ('Sangeetha', Decimal('32256.00')),
#  ('Anjappar', Decimal('47340.00')),
#  ('Copper Kitchen', Decimal('36712.00')),
#  ('Barbeque Nation', Decimal('33929.00')),
#  ('The Bowl Company', Decimal('45766.00')),
#  ('Wow Momo', Decimal('35465.00')),
#  ('Hotel Saravana', Decimal('32102.00'))]

# %% [markdown]
# # Question 38 (INNER JOIN ⭐⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy management team wants to generate a complete order report.
#
# For every order, display:
#
# - order_id
# - customer_name
# - restaurant_name
# - partner_name
# - total_amount
#
# ---
#
# ## Requirements
#
# Join the following tables:
#
# - customers
# - orders
# - restaurants
# - delivery_partners
#
# Use:
#
# - INNER JOIN
# - Table Aliases
#
# ---
#
# ## Tables
#
# ### customers
#
# - customer_id
# - customer_name
#
# ### orders
#
# - order_id
# - customer_id
# - restaurant_id
# - partner_id
# - total_amount
#
# ### restaurants
#
# - restaurant_id
# - restaurant_name
#
# ### delivery_partners
#
# - partner_id
# - partner_name
#
# ---
#
# ## Relationships
#
# customers.customer_id (PK)
#
# ↓
#
# orders.customer_id (FK)
#
# ----------------------------
#
# restaurants.restaurant_id (PK)
#
# ↓
#
# orders.restaurant_id (FK)
#
# ----------------------------
#
# delivery_partners.partner_id (PK)
#
# ↓
#
# orders.partner_id (FK)
#
# ---
#
# ## Expected Output
#
# | order_id | customer_name | restaurant_name | partner_name | total_amount |
# |----------|---------------|-----------------|--------------|-------------:|
# | 101 | Rahul | A2B | Ravi | 850 |
# | 102 | Priya | KFC | Kumar | 1200 |
# | ... | ... | ... | ... | ... |
#
# ---
#
# ## Hint
#
# Think about the `orders` table.
#
# It acts as the **central table**.
#
# ```
#               Customers
#                   │
#                   │
#                   ▼
# Restaurants → Orders ← Delivery Partners
# ```
#
# Every relationship starts from the **orders** table.
#
# ---
#
# ## Challenge
#
# - No subqueries.
# - No SELECT *.
# - Use proper aliases.
# - Join all four tables correctly.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐

# %%
# %%sql
# SELECT
# 	c.customer_id,
# 	c.customer_name,
# 	o.order_id,
# 	o.customer_id,
# 	o.restaurant_id,
# 	o.partner_id,
# 	o.total_amount,
# 	r.restaurant_id,
# 	r.restaurant_name
#
# FROM orders o
#
# INNER JOIN customers c
# ON c.customer_id = o.customer_id
#
# INNER JOIN restaurants r
# ON r.restaurant_id = o.restaurant_id
#
# INNER JOIN delivery_partners dp
# ON dp.partner_id = o.partner_id;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 500 rows affected.
# [(51, 'Vijay51', 12, 51, 1, 2, Decimal('1219.00'), 1, 'A2B'),
#  (66, 'Nisha66', 25, 66, 1, 14, Decimal('252.00'), 1, 'A2B'),
#  (46, 'Karthik46', 38, 46, 1, 16, Decimal('2162.00'), 1, 'A2B'),
#  (77, 'Arun77', 55, 77, 1, 4, Decimal('1065.00'), 1, 'A2B'),
#  (70, 'Ajay70', 64, 70, 1, 28, Decimal('1130.00'), 1, 'A2B'),
#  (77, 'Arun77', 67, 77, 1, 12, Decimal('2131.00'), 1, 'A2B'),
#  (28, 'Suresh28', 68, 28, 1, 18, Decimal('1422.00'), 1, 'A2B'),
#  (85, 'Gokul85', 78, 85, 1, 20, Decimal('1724.00'), 1, 'A2B'),
#  (5, 'Suresh5', 79, 5, 1, 12, Decimal('321.00'), 1, 'A2B'),
#  (7, 'Rahul7', 140, 7, 1, 13, Decimal('2008.00'), 1, 'A2B'),
#  (87, 'Ramesh87', 144, 87, 1, 2, Decimal('571.00'), 1, 'A2B'),
#  (64, 'Suresh64', 147, 64, 1, 28, Decimal('750.00'), 1, 'A2B'),
#  (83, 'Keerthi83', 153, 83, 1, 18, Decimal('375.00'), 1, 'A2B'),
#  (2, 'Deepa2', 162, 2, 1, 22, Decimal('1883.00'), 1, 'A2B'),
# ...

# %% [markdown]
# # Question 39 (INNER JOIN ⭐⭐⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy finance team wants a complete payment report.
#
# Display:
#
# - order_id
# - customer_name
# - restaurant_name
# - partner_name
# - payment_method
# - payment_status
# - total_amount
#
# ---
#
# ## Requirements
#
# Join:
#
# - customers
# - orders
# - restaurants
# - delivery_partners
# - payments
#
# Use only:
#
# - INNER JOIN
# - Table Aliases
#
# ---
#
# ## Relationships
#
# customers.customer_id (PK)
#
# ↓
#
# orders.customer_id (FK)
#
# ----------------------------
#
# restaurants.restaurant_id (PK)
#
# ↓
#
# orders.restaurant_id (FK)
#
# ----------------------------
#
# delivery_partners.partner_id (PK)
#
# ↓
#
# orders.partner_id (FK)
#
# ----------------------------
#
# orders.order_id (PK)
#
# ↓
#
# payments.order_id (FK)
#
# ---
#
# ## Expected Output
#
# | order_id | customer_name | restaurant_name | partner_name | payment_method | payment_status | total_amount |
# |----------|---------------|-----------------|--------------|----------------|----------------|-------------:|
# | 101 | Rahul | A2B | Ravi | UPI | Success | 850 |
# | 102 | Priya | KFC | Kumar | Credit Card | Success | 1200 |
# | ... | ... | ... | ... | ... | ... | ... |
#
# ---
#
# ## Challenge
#
# - Join all **5 tables**.
# - Use proper aliases.
# - Return only the required columns.
# - Do not use `SELECT *`.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐⭐ (Interview Level)

# %%
# %%sql
# SELECT
# 	o.order_id,
# 	c.customer_name,
# 	r.restaurant_name,
# 	dp.partner_name,
# 	p.payment_type,
# 	p.payment_status,
# 	o.total_amount
#
# FROM orders o
#
# INNER JOIN customers c
# ON c.customer_id = o.customer_id
#
# INNER JOIN restaurants r
# ON r.restaurant_id = o.restaurant_id
#
# INNER JOIN delivery_partners dp
# ON dp.partner_id = o.partner_id
#
# INNER JOIN payments p
# ON p.order_id = o.order_id;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 500 rows affected.
# [(12, 'Vijay51', 'A2B', 'Partner_2', 'Wallet', 'Success', Decimal('1219.00')),
#  (25, 'Nisha66', 'A2B', 'Partner_14', 'Credit Card', 'Pending', Decimal('252.00')),
#  (38, 'Karthik46', 'A2B', 'Partner_16', 'UPI', 'Refunded', Decimal('2162.00')),
#  (55, 'Arun77', 'A2B', 'Partner_4', 'Net Banking', 'Failed', Decimal('1065.00')),
#  (64, 'Ajay70', 'A2B', 'Partner_28', 'Debit Card', 'Failed', Decimal('1130.00')),
#  (67, 'Arun77', 'A2B', 'Partner_12', 'UPI', 'Success', Decimal('2131.00')),
#  (68, 'Suresh28', 'A2B', 'Partner_18', 'Net Banking', 'Pending', Decimal('1422.00')),
#  (78, 'Gokul85', 'A2B', 'Partner_20', 'Debit Card', 'Pending', Decimal('1724.00')),
#  (79, 'Suresh5', 'A2B', 'Partner_12', 'UPI', 'Success', Decimal('321.00')),
#  (140, 'Rahul7', 'A2B', 'Partner_13', 'UPI', 'Success', Decimal('2008.00')),
#  (144, 'Ramesh87', 'A2B', 'Partner_2', 'Cash', 'Success', Decimal('571.00')),
# ...

# %% [markdown]
# # Question 40 (LEFT JOIN ⭐⭐)
#
# ## Scenario
#
# The Swiggy management team wants to generate a report of **all customers**, including those who **have never placed an order**.
#
# Write a SQL query to display:
#
# - customer_id
# - customer_name
# - order_id
# - total_amount
#
# ---
#
# ## Requirements
#
# - Use **LEFT JOIN**.
# - The `customers` table should be the **left table**.
# - Display all customers.
# - If a customer has not placed an order, their `order_id` and `total_amount` should appear as **NULL**.
#
# ---
#
# ## Expected Concepts
#
# - LEFT JOIN
# - Primary Key
# - Foreign Key
# - Table Aliases
#
# ---
#
# ## Tables Involved
#
# ### customers
#
# | Column |
# |---------|
# | customer_id |
# | customer_name |
#
# ### orders
#
# | Column |
# |---------|
# | order_id |
# | customer_id |
# | total_amount |
#
# ---
#
# ## Expected Output
#
# | customer_id | customer_name | order_id | total_amount |
# |-------------|---------------|---------:|-------------:|
# | 1 | Rahul | 101 | 850 |
# | 2 | Priya | 102 | 1200 |
# | 3 | Arjun | NULL | NULL |
#
# > **Note:** If your current dataset has every customer placing at least one order, you may not see any `NULL` values. The query is still correct.
#
# ---
#
# ## Hint
#
# Relationship:
#
# ```text
# customers.customer_id (PK)
#
# ↓
#
# orders.customer_id (FK)
# ```
#
# Think about:
#
# ```text
# Customers
#
# ↓
#
# Keep ALL Customers
#
# ↓
#
# Find Matching Orders
#
# ↓
#
# No Match?
#
# ↓
#
# Return NULL
# ```
#
# ---
#
# ## Challenge
#
# - Do not use `INNER JOIN`.
# - Do not use `RIGHT JOIN`.
# - Use table aliases.
# - Do not use `SELECT *`.
#
# ---
#
# **Difficulty Level:** ⭐⭐ Easy

# %%
# %%sql
#
# select c.customer_id,
# 	c.customer_name,
# 	o.order_id,
# 	o.total_amount
# from customers c
# left join orders o
# on c.customer_id = o.customer_id
# order by o.total_amount;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 504 rows affected.
# [(19, 'Suresh19', None, None),
#  (101, 'Rohit Kumar', None, None),
#  (102, 'Anjali Devi', None, None),
#  (104, 'John', None, None),
#  (91, 'Divya91', 399, Decimal('170.00')),
#  (20, 'Sneha20', 398, Decimal('182.00')),
#  (53, 'Ramesh53', 450, Decimal('184.00')),
#  (60, 'Divya60', 256, Decimal('188.00')),
#  (94, 'Lavanya94', 310, Decimal('192.00')),
#  (92, 'Suresh92', 44, Decimal('194.00')),
#  (76, 'Arun76', 84, Decimal('195.00')),
#  (56, 'Rahul56', 97, Decimal('197.00')),
#  (75, 'Meena75', 406, Decimal('198.00')),
#  (16, 'Anitha16', 246, Decimal('202.00')),
#  (97, 'Lavanya97', 337, Decimal('209.00')),
#  (38, 'Arun38', 437, Decimal('210.00')),
#  (57, 'Priya57', 184, Decimal('212.00')),
#  (47, 'Pooja47', 40, Decimal('213.00')),
#  (42, 'Lavanya42', 475, Decimal('220.00')),
#  (75, 'Meena75', 190, Decimal('221.00')),
#  (79, 'Ajay79', 61, Decimal('223.00')),
#  (52, 'Nisha52', 108, Decimal('228.00')),
# ...

# %% [markdown]
# # Question 41 (LEFT JOIN ⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy marketing team wants to identify **customers who have never placed an order**.
#
# Display:
#
# - customer_id
# - customer_name
# - city
#
# ---
#
# ## Requirements
#
# - Use LEFT JOIN.
# - Display only customers who do **not** have any orders.
# - Do **not** use `NOT EXISTS`.
# - Do **not** use a subquery.
#
# ---
#
# ## Expected Concepts
#
# - LEFT JOIN
# - IS NULL
#
# ---
#
# ## Hint
#
# Customers
#
# ↓
#
# LEFT JOIN Orders
#
# ↓
#
# Customers without matching orders
#
# ↓
#
# Which column from the `orders` table becomes NULL?
#
# ↓
#
# Use that column in the WHERE clause.
#
# ---
#
# ## Challenge
#
# - No subqueries.
# - No EXISTS.
# - No NOT IN.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐

# %%
# %%sql
# select c.customer_id,
# 	c.customer_id,
# 	c.customer_name,
# city
# from customers c
# left join orders o
# on c.customer_id = o.customer_id
# where o.total_amount IS NULL;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 4 rows affected.
# [(19, 19, 'Suresh19', 'Bangalore'),
#  (101, 101, 'Rohit Kumar', 'Chennai'),
#  (102, 102, 'Anjali Devi', 'Bangalore'),
#  (104, 104, 'John', 'Chennai')]

# %% [markdown]
# # Question 42 (LEFT JOIN ⭐⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy management team wants to know **how many orders each customer has placed**.
#
# Display:
#
# - customer_id
# - customer_name
# - total_orders
#
# Important:
#
# Even customers who have **never placed an order** should appear.
#
# Their `total_orders` should be **0**.
#
# ---
#
# ## Requirements
#
# - Use LEFT JOIN.
# - Use COUNT().
# - Use GROUP BY.
# - Include customers with zero orders.
#
# ---
#
# ## Expected Output
#
# | customer_id | customer_name | total_orders |
# |-------------|---------------|-------------:|
# | 1 | Rahul | 5 |
# | 2 | Priya | 3 |
# | 101 | Rohit Kumar | 0 |
# | 102 | Anjali Devi | 0 |
#
# ---
#
# ## Hint
#
# Think carefully.
#
# After the LEFT JOIN:
#
# ```
# John
#
# ↓
#
# order_id = NULL
# ```
#
# Now ask yourself:
#
# Should you use
#
# ```sql
# COUNT(*)
# ```
#
# or
#
# ```sql
# COUNT(o.order_id)
# ```
#
# One of them will give the wrong answer for customers with no orders.
#
# ---
#
# ## Challenge
#
# - No subqueries.
# - No EXISTS.
# - Use only LEFT JOIN.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐

# %%
# %%sql
# select c.customer_id,
# 	c.customer_name,
# 	count(o.order_id) as total_orders
# from customers c
# left join orders o
# on c.customer_id = o.customer_id
# group by c.customer_name,c.customer_id
# order by total_orders;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 103 rows affected.
# [(19, 'Suresh19', 0),
#  (101, 'Rohit Kumar', 0),
#  (102, 'Anjali Devi', 0),
#  (104, 'John', 0),
#  (33, 'Sneha33', 1),
#  (61, 'Harish61', 1),
#  (9, 'Gokul9', 2),
#  (14, 'Nisha14', 2),
#  (25, 'Ramesh25', 2),
#  (27, 'Karthik27', 2),
#  (38, 'Arun38', 2),
#  (45, 'Priya45', 2),
#  (48, 'Anitha48', 2),
#  (67, 'Rahul67', 2),
#  (78, 'Anitha78', 2),
#  (80, 'Anitha80', 2),
#  (81, 'Pooja81', 2),
#  (98, 'Nisha98', 2),
#  (4, 'Rahul4', 3),
#  (5, 'Suresh5', 3),
#  (6, 'Keerthi6', 3),
#  (11, 'Keerthi11', 3),
#  (24, 'Deepa24', 3),
#  (26, 'Nisha26', 3),
#  (39, 'Vijay39', 3),
#  (50, 'Gokul50', 3),
#  (55, 'Gokul55', 3),
#  (62, 'Harish62', 3),
#  (65, 'Divya65', 3),
#  (94, 'Lavanya94', 3),
#  (99, 'Divya99', 3),
#  (1, 'Nisha1', 4),
#  (3, 'Ajay3', 4),
#  (7, 'Rahul7', 4),
#  (31, 'Gokul31', 4),
#  (40, 'Gokul40', 4),
#  (41, 'Meena41', 4),
#  (42, 'Lavanya42', 4),
#  (44, 'Lavanya44', 4),
# ...

# %% [markdown]
# # Question 43 (LEFT JOIN ⭐⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy operations team wants to know **how many orders each restaurant has received**.
#
# Display:
#
# - restaurant_id
# - restaurant_name
# - total_orders
#
# Important:
#
# Even restaurants that have **never received an order** should appear.
#
# Their **total_orders** should be **0**.
#
# ---
#
# ## Requirements
#
# - Use **LEFT JOIN**.
# - Use **COUNT()**.
# - Use **GROUP BY**.
# - Display all restaurants.
#
# ---
#
# ## Expected Concepts
#
# - LEFT JOIN
# - GROUP BY
# - COUNT()
# - Aggregate Functions
#
# ---
#
# ## Tables Involved
#
# ### restaurants
#
# | Column |
# |---------|
# | restaurant_id |
# | restaurant_name |
#
# ### orders
#
# | Column |
# |---------|
# | order_id |
# | restaurant_id |
#
# ---
#
# ## Expected Output
#
# | restaurant_id | restaurant_name | total_orders |
# |--------------:|-----------------|-------------:|
# | 1 | A2B | 35 |
# | 2 | KFC | 28 |
# | 21 | ABC Restaurant | 0 |
# | 22 | XYZ Kitchen | 0 |
#
# > **Note:** If every restaurant in your current dataset has at least one order, you may not see any restaurant with `0` orders. The query is still correct.
#
# ---
#
# ## Hint
#
# Think carefully.
#
# Which table should be on the **left side**?
#
# ```
# Restaurants
#
# ↓
#
# LEFT JOIN
#
# ↓
#
# Orders
# ```
#
# Why?
#
# Because we want **every restaurant**.
#
# ---
#
# ## Challenge
#
# - Do not use subqueries.
# - Do not use EXISTS.
# - Do not use SELECT *.
# - Use the correct COUNT() function.
#
# ---
#
# ## Difficulty Level
#
# ⭐⭐⭐⭐

# %%
# %%sql
# select
# 	r.restaurant_id,
# 	r.restaurant_name,
# 	count(o.order_id)  as total_orders
# from restaurants r
# left join orders o
# on r.restaurant_id = o.restaurant_id
# group by r.restaurant_name,restaurant_id
# order by total_orders;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 20 rows affected.
# [(6, 'Subway', 17),
#  (17, 'Buhari', 18),
#  (20, 'Salem RR', 19),
#  (3, 'Pizza Hut', 20),
#  (16, 'EatFit', 20),
#  (4, 'KFC', 21),
#  (7, 'Behrouz Biryani', 21),
#  (10, 'Sangeetha', 22),
#  (13, 'Barbeque Nation', 24),
#  (19, 'Hotel Saravana', 24),
#  (18, 'Hot Chips', 25),
#  (8, 'Burger King', 26),
#  (9, 'SS Hyderabad Biryani', 26),
#  (15, 'Wow Momo', 26),
#  (2, 'Dominos', 28),
#  (12, 'Copper Kitchen', 28),
#  (5, 'McDonalds', 31),
#  (14, 'The Bowl Company', 32),
#  (1, 'A2B', 33),
#  (11, 'Anjappar', 39)]

# %% [markdown]
# # Question 44 (LEFT JOIN + IS NULL ⭐⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy operations team wants to identify **restaurants that have never received any orders**.
#
# Write a SQL query to display:
#
# - restaurant_id
# - restaurant_name
# - city
#
# Display only the restaurants that **do not have any orders**.
#
# ---
#
# ## Requirements
#
# - Use **LEFT JOIN**.
# - Use **IS NULL**.
# - Do **not** use subqueries.
# - Do **not** use `NOT EXISTS`.
# - Do **not** use `NOT IN`.
#
# ---
#
# ## Expected Concepts
#
# - LEFT JOIN
# - IS NULL
# - Primary Key
# - Foreign Key
#
# ---
#
# ## Tables Involved
#
# ### restaurants
#
# | Column |
# |---------|
# | restaurant_id |
# | restaurant_name |
# | city |
#
# ### orders
#
# | Column |
# |---------|
# | order_id |
# | restaurant_id |
#
# ---
#
# ## Expected Output
#
# | restaurant_id | restaurant_name | city |
# |--------------:|-----------------|-----------|
# | 21 | Food Palace | Chennai |
# | 22 | Grill House | Bangalore |
# | ... | ... | ... |
#
# > **Note:** If every restaurant in your current dataset has at least one order, the query may return **0 rows**. To test this query, insert a new restaurant without creating any orders for it.
#
# ---
#
# ## Hint
#
# Think about the execution:
#
# ```text
# Restaurants
#
# ↓
#
# LEFT JOIN Orders
#
# ↓
#
# Restaurants without matching orders
#
# ↓
#
# Which column from the Orders table becomes NULL?
#
# ↓
#
# Filter using WHERE ... IS NULL
# ```
#
# ---
#
# ## Challenge
#
# - Use the correct column in the `WHERE` clause.
# - Use only one JOIN.
# - Return only the required columns.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐

# %%
# %%sql
# select
#     r.restaurant_id,
#     r.restaurant_name,
#     r.city
# from restaurants r
# left join orders o
# on r.restaurant_id = o.restaurant_id
# where o.total_amount IS NULL;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# [(21, 'Test Restaurant', 'Chennai'), (22, 'Test Restaurant', 'Chennai')]

# %% [markdown]
# # Question 45 (LEFT JOIN + 3 Tables ⭐⭐⭐⭐)
#
# ## Scenario
#
# The Swiggy management team wants a report showing **all customers** and, if available:
#
# - the restaurant from which they ordered
# - the order amount
#
# Customers who have **never placed an order** should also appear.
#
# ---
#
# ## Display
#
# - customer_id
# - customer_name
# - restaurant_name
# - total_amount
#
# ---
#
# ## Requirements
#
# - Use **LEFT JOIN**.
# - Join:
#   - customers
#   - orders
#   - restaurants
# - Display **all customers**.
# - If a customer has not placed an order, `restaurant_name` and `total_amount` should be **NULL**.
#
# ---
#
# ## Tables
#
# ### customers
#
# | Column |
# |---------|
# | customer_id |
# | customer_name |
#
# ### orders
#
# | Column |
# |---------|
# | order_id |
# | customer_id |
# | restaurant_id |
# | total_amount |
#
# ### restaurants
#
# | Column |
# |---------|
# | restaurant_id |
# | restaurant_name |
#
# ---
#
# ## Relationships
#
# ```
# customers.customer_id (PK)
#
# ↓
#
# orders.customer_id (FK)
#
# ↓
#
# orders.restaurant_id (FK)
#
# ↓
#
# restaurants.restaurant_id (PK)
# ```
#
# ---
#
# ## Expected Output
#
# | customer_id | customer_name | restaurant_name | total_amount |
# |-------------|---------------|-----------------|-------------:|
# | 1 | Rahul | A2B | 850 |
# | 2 | Priya | KFC | 1200 |
# | 101 | Rohit Kumar | NULL | NULL |
# | 102 | Anjali Devi | NULL | NULL |
#
# ---
#
# ## Hint
#
# Think in this order:
#
# ```
# Customers
#
# ↓
#
# LEFT JOIN Orders
#
# ↓
#
# LEFT JOIN Restaurants
# ```
#
# Ask yourself:
#
# - Which table do we want completely?
# - Which joins should be LEFT JOIN?
# - Which table depends on the previous join?
#
# ---
#
# ## Challenge
#
# - No subqueries.
# - No EXISTS.
# - No SELECT *.
# - Use proper table aliases.
#
# ---
#
# **Difficulty Level:** ⭐⭐⭐⭐

# %%
# %%sql
#
# select
# 	c.customer_id,
# 	c.customer_name,
# 	r.restaurant_name,
# 	o.total_amount
#
# from customers c
#
# LEFT JOIN orders o
# ON c.customer_id = o.customer_id
#
#
# LEFT JOIN restaurants r
# ON r.restaurant_id = o.restaurant_id
# order by customer_id desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 504 rows affected.
# [(104, 'John', None, None),
#  (102, 'Anjali Devi', None, None),
#  (101, 'Rohit Kumar', None, None),
#  (100, 'Gokul100', 'Salem RR', Decimal('2385.00')),
#  (100, 'Gokul100', 'Hot Chips', Decimal('1272.00')),
#  (100, 'Gokul100', 'Buhari', Decimal('832.00')),
#  (100, 'Gokul100', 'Copper Kitchen', Decimal('1736.00')),
#  (99, 'Divya99', 'Burger King', Decimal('1602.00')),
#  (99, 'Divya99', 'McDonalds', Decimal('868.00')),
#  (99, 'Divya99', 'Wow Momo', Decimal('840.00')),
#  (98, 'Nisha98', 'Dominos', Decimal('309.00')),
#  (98, 'Nisha98', 'Copper Kitchen', Decimal('2049.00')),
#  (97, 'Lavanya97', 'McDonalds', Decimal('1152.00')),
#  (97, 'Lavanya97', 'Hotel Saravana', Decimal('630.00')),
#  (97, 'Lavanya97', 'Buhari', Decimal('1414.00')),
#  (97, 'Lavanya97', 'Buhari', Decimal('921.00')),
#  (97, 'Lavanya97', 'Wow Momo', Decimal('209.00')),
#  (97, 'Lavanya97', 'Burger King', Decimal('2197.00')),
# ...
